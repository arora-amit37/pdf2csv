# %% [markdown]
# ## Imports

# %%
import pytesseract
from pdf2image import convert_from_path
import os
import re

import pandas as pd
# Set the maximum number of columns to None (unlimited)
pd.set_option('display.max_columns', None)

import numpy as np
import zipfile
from PIL import Image, ImageFilter, ImageOps
import io
import csv
from thefuzz import process # Install via: pip install thefuzz
import glob
import pickle
import multiprocessing as mp

# %%
# --- PATHS ---
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
poppler_bin_path = r'C:\poppler\poppler-25.12.0\Library\bin' 
input_file = r'C:\pdf2csv\extracted_files\recovered\6852.pdf'

# %% [markdown]
# # High Quality

# %%
try:
    print("1. Converting PDF to high-resolution image...")
    images = convert_from_path(
        input_file,
        dpi=400,
        first_page=1,
        last_page=1,
        poppler_path=poppler_bin_path
    )

    print("2. Preprocessing image for OCR...")
    img = images[0]

    img = img.convert("L")
    img = ImageOps.autocontrast(img)
    img = img.filter(ImageFilter.MedianFilter(size=3))
    img = img.point(lambda x: 0 if x < 160 else 255, "1")

    print("3. Running OCR (optimized for scanned documents)...")
    custom_config = r'-l eng --oem 3 --psm 4 -c preserve_interword_spaces=1'
    text = pytesseract.image_to_string(img, config=custom_config)

    print("4. Cleaning OCR text...")
    lines = [line.strip() for line in text.splitlines() if line.strip()]

    data = []
    for line in lines:
        line = line.replace(" ,", ",").replace(", ", ",")
        data.append(line.split(","))

    print("5. Writing CSV...")
    df = pd.DataFrame(data)

except Exception as e:
    print(f"Error: {e}")
    
data

# %%
data[1]

# %%
def extract_ocr_data(data_list):
    # 1. Clean and Join: Remove noise characters but keep structure
    raw_text = " ".join(data_list)
    # Remove common OCR artifacts that break numbers
    clean_text = re.sub(r'[“”‘’"°*]', '', raw_text)
    parts = clean_text.split()
    
    # 2. Extract Dates (Handling formats like 1/22/1993, 10.23.2002, or split 12 23 1992)
    # This finds 4-digit years and looks backwards for the month/day
    dates = []
    date_pattern = r'(\d{1,2}[/.-]\d{1,2}[/.-]\d{4}|\d{1,2}[/.-]\d{4})'
    found_dates = re.findall(date_pattern, clean_text)
    
    # If dates are split by spaces (e.g., '12', '23', '1992'), we reconstruct them
    if not found_dates:
        for i in range(len(parts)):
            if len(parts[i]) == 4 and parts[i].isdigit(): # Found a year
                if i >= 2 and parts[i-1].isdigit() and parts[i-2].isdigit():
                    found_dates.append(f"{parts[i-2]}/{parts[i-1]}/{parts[i]}")
    
    # 3. Dynamic Field Extraction
    
    # Lender: Usually the first 2-3 words
    lender = " ".join([p for p in parts[:3] if not any(c.isdigit() for c in p)])
    
    # Status: Find specific keywords
    es_status = next((p for p in parts if "Terminated" in p), "Unknown")
    
    # Numbers: Find all decimals and integers
    numbers = re.findall(r'\d+\.\d+|\d+', clean_text)
    
    # Ages: Usually 2-digit numbers between 62 and 99
    ages = [n for n in numbers if 62 <= float(n) <= 100 and len(n) == 2]
    borr_age = ages[0] if len(ages) > 0 else "no data"
    coborr_age = ages[1] if len(ages) > 1 else "no data"
    
    # Interest Rate: Usually a decimal like 7.99 or 8.27
    rates = [n for n in numbers if "." in n and 2 <= float(n) <= 15]
    int_rt = rates[0] if rates else "0.00"
    
    # Zip Code: 5 digit number
    zip_code = [n for n in numbers if len(n) == 5]
    prop_zip = zip_code[0] if zip_code else "00000"
    
    # Financial Amounts: Large numbers (Claim Amount and Principal Limit)
    amounts = [n for n in numbers if float(n) > 5000 and len(n) > 4]
    max_clm = amounts[0] if len(amounts) > 0 else "0"
    init_limit = amounts[1] if len(amounts) > 1 else "0"

    # Flag Extraction (Searching for specific characters N, A, T)
    pd_stmln = "N" if "N" in clean_text.upper() else "Y"
    rt_typ = "A" if "A" in clean_text.upper() else "F"
    arm_indx = "T" if "T" in clean_text.upper() else "N"

    # 4. Map to your exact list structure
    mapped_output = [
        lender,
        found_dates[0] if len(found_dates) > 0 else "no data",
        found_dates[1] if len(found_dates) > 1 else "no data",
        found_dates[2] if len(found_dates) > 2 else "no data",
        borr_age,
        coborr_age,
        "1", # Default count
        es_status,
        int_rt,
        "0.0", # int_rt_10yr
        "0.0", # hecm_margin
        pd_stmln,
        rt_typ,
        arm_indx,
        "1Y", # arm_prdc_typ
        max_clm,
        init_limit,
        "0", # fees
        prop_zip,
        "02" # loan_typ
    ]
    
    return ", ".join(map(str, mapped_output))

# Test with one of your problematic rows
row = ['UNETY', 'MORTGAGE', 'CORP', '12', '23', '1992', '3.25', '1994', '10', '15', '1999', '81', '74', '20', '8.39', 'H.', '39', 'BN', '"A', '1', 'Ww', 'Loz700', '60490.', '5', 'on']
print(extract_ocr_data(row))

# %% [markdown]
# # Low Quality

# %%
try:
    print("1. Converting PDF to Image...")
    images = convert_from_path(input_file, first_page=1, last_page=1, poppler_path=poppler_bin_path)
    
    print("2. Running OCR with Table Segmentation...")
    # --psm 6 tells Tesseract to treat the image as a single uniform block of text
    custom_config = r'--oem 3 --psm 6'
    text = pytesseract.image_to_string(images[0], config=custom_config)

except Exception as e:
    print(f"\nError: {e}")
# Out:
# 1. Converting PDF to Image...
# 2. Running OCR with Table Segmentation...

# %%
text
# Out:
# '("BANK OF AMERICA NA CHARLOTTE’ 2/5/2010] _3/s/aonof | 5] sof |Endorsed @T2.970f Pfu ae 23z0007 7206] sooo [97741 "02"\n[|METLIFE BANK, NATIONAL aSsocrATION’ | 1720/2010] 2/aa/aono[ eo] Assigned [5.56] 56] fins eT to6000/2asaza| 5000 [970 "02" |\n["BANK OF AMERICA NA CHARLOTTE’ | 2/5/2010] 3/4/2010] 12/ao/eors| 66] | | Terminated’ | 2.970) 63a] rs fut ae 87o00| 92565] azo o7a1a "02"\n[TRINANCIAL FREEDOM ACQUISITION LLC’ | 2/2/2010] s/i/ao10[77as/aor9| | | Terminatea [5.56] 56] fn 220000136400 4200 |" 97702 "02" |\n[LAND HOME FINANCIAL SERVICES, INC.’ | 3/26/2010] _a/a6/2oi0| | so] | Assigned ‘| 5.56) 5.56] oft’ th 2500] s69670.5] sooo 97110 * "02"\n[GENERATION MORTGAGE CowpANY’ | 2/7/2010] 3/9/2010|9/is/aoia| || | "Terminated’ | 48299] as ftNh wim 20000] azs6z0[az00["97ia1 "02"\n[TFINANCIAL FREEDOM ACQUISITION LLC’ | 2/22/2010] s/ig/2oi0| | sa] | Assigned \' | 5.56) 5.56] oft th 320000 tzasto] gg99 [97132 "on"\n[METLIFE BANK, NATIONAL AssocraTion’ | a/5/2010|2/aa/a0i0| | wat Assigned “| s6f 56 ofnh te zs000| gas] as00["97iz8 "02"\n[\'BANK OF AMERICA NA CHARLOTTE’ | avugvzoi0| s/aaaoiof | to] | Assigned \' | 5.56) 5.56] oft th 500| s7si0] sooo 97816 *|*o2"\n[JAMES B NUTTER AND CompANY’ | a/27/a010|2/i9/20i0| 12/28/eoi2| | Terminated’ | aarf 6] NT wim 09000|azzap0[ 4090 [97479 "02"\n[WELLS FARGO BANK NA’ | eziazouo] a/iv/znio| | taf ta] | Assigned * | 5.a9] ag} oth tt p20000/ 43000] az00|\'97i03 02"\n[\'MSR ASSET VEHICLE LLC’ aft aono|3/ii/eoi0| || || Assigned “| 556 56] ftnh te gr0000| 239440 eo00 [97527 "02"\n"BANK OF AMERICA NA CHARLOTTE’ | 3/5/2010] avo/2oi0|_ | | 80] | Assigned ‘| 5.56] 5.56] ony tt aragoo| isogi2] ras |\'97aa8 "02"\n"PLAZA HOME WORTGAGE, INC.’ | 2/9 /aon0|3/io/zn0| | wf Assigned “| a s6f 56] ony 395000 azig90[ 4000 [97498 "02"\n"BANK OP AMERICA NA CHARLOTTE | a/i7yaoi0| 3/12/2010] i2/ui/eoiz] taf | Terminated’ | 5.56] 5.56] oft’ te 65000] t06095/ 3300 [97236 f\'o2"\n"BANK OF AMERICA NA CHARLOTTE’ | a/a6/20i0| 2/16/2010] 7/26/aois| | | Terminated’ | 5.56] 556] ony te azzo00]aaei00 44097338 "02"\n[GENERATION MORTGAGE ComPaNY’ | 2/25/2010] 3/18/2010] 10/3/2016] | | Terminated’ | 479] tf] 8.25 eh tytn is gazo00| 262389] goo 9713302"\n[VJAMES B NUTTER AND Company’ | a//a0n0| 4/7/2010] 4/9/a0n0| | | Terminated’ | aa7af 69] a5 tnh whims a55000[igz6s5[ asso ["o7a4s "02"\n"BANK OP AMERICA NA CHARLOTTE’ | /27/2010| 2/23/2010] i2/ii/eoi3]_ tif | Terminated’ | 2.981 gf] 5 teh yh is 233000] tzegio] 4330 [ "97504 02"\n[TRINANCE OF AMERICA REVERSE LLC’ | 3/2/2010] a/e/ao10|vai/aons| 82] | | Terminated’ | 5.56) 5.6] ft 65000 a60610] 5650 | "97051 "02" |\n[\'SIBRRA PACIFIC NorTGAGE’ | zayzoi0| s/is/eonof | ta] || Bndorsed | 3.495] 97] ast ae at5000| tezs625] aso |\'97365__* "02"\n[ "BANK OF AMERICA NA CHARLOTTE’ | 71572010] 2/aa/eonof ea] | tindorsed TT 5.56) 56] one 230000 [1s2za8o[ 400 [97146 "02" |\n["BANK OF AMERICA NA CHARLOTTE’ | 2/6/2010] 3/4/2010} s/iv/eors| 6a] | | Terminated’ | 5.56) 5.6] tnt 5500/5095] a0 [97211 "02"\n[TJAMES B NUTTER AND COwPANY | 2/8/2010] 3/i/2010|97ai/aors| 86] P| terminated [sara fina tz000 [7688 | 2500 [97479 "02" |\n[\'BANK OF AMERICA NA CHARLOTTE’ | 25/2010] 2/22/2010] 6/ao/aoi6| 72] | | Terminated’ | 5.56) 5.56] ott ts 70000| 22360] 570097415 * "02"\n[ANTEC FUNDING GROUP Luc’ | a/t/oono|a/io/zno| Pf Endorsed "| 2979 6 Pf wu ims 28000] azzaan[s280["97230 "02"\n[\'BANK OF AMERICA NA CHARLOTTE’ | 15/2010] 2/16/2010| 7/ea/eoi6| 8] | | Terminated’ | 2.983) a] rst tt | t6000| tazg3] 3220|"97206_* "02"\n[TPINANCTAL FREEDOM ACQUISITION LLC’ | 3/9/2010 4/9/2010] ui2a/aoia| | Terminated’ | 5.5656] fey te p39000]a6i325[s90["97203 "02"\n[\'AMTEC FUNDING GRouP Luc’ | atzz0i0| 3/ue/aoiof | ta] | Assigned \' | 5.56) 5.56] oft 5000/6825] a7s0|\'97376__* "02"\n["BANK OF AMERICA NA CHARLOTTE’ | a/zya0i0|6/i/zni0| | a] | Assigned “| 556 56] fn 321000] zoassof 420 ["o7s74a "02"\n[WELLS FARGO BANK NA’ | aiz/aqi0| 3/24/2010] svis/aoi7]|_ ea | 66 | | Terminated’ | 5.49] ag} ath 315000) 79235] 950 |\'97739 02 ...

# %%
target_columns = [
    'lender', 'clsing_dt', 'endrsmt_dt', 'tmntn_dt', 'Borr_Age', 
    'Coborr_Age', 'Borr_Cnt', 'es_status', 'int_rt', 'int_rt_10yr', 
    'hecm_margin', 'pd_stmln_flg', 'rt_typ', 'arm_indx_typ', 
    'arm_prdc_typ', 'max_clm_amt', 'init_prncpl_lmt', 
    'hecm_orgntn_fees', 'prop_addr_zip_cd', 'loan_typ'
]

def robust_parse(line):
    row = [None] * 20

    # ---------- OCR NORMALIZATION ----------
    line = (
        line.replace('”', '"')
            .replace("’", "'")
            .replace('!', '')
            .replace('|', ' ')
    )

    # ---------- PATTERN EXTRACTION ----------
    dates = re.findall(r'\d{1,2}/\d{1,2}/\d{2,4}', line)
    decimals = re.findall(r'\d+\.\d+', line)

    # Remove dates & decimals before integer parsing
    clean_text = re.sub(r'\d{1,2}/\d{1,2}/\d{2,4}', ' ', line)
    clean_text = re.sub(r'\d+\.\d+', ' ', clean_text)
    numbers = re.findall(r'\b\d+\b', clean_text)

    # ---------- LENDER ----------
    lender_match = re.search(r'^(.*?)(?=\d{1,2}/)', line)
    row[0] = lender_match.group(1).strip().strip('"').strip("'") if lender_match else None

    # ---------- DATES ----------
    if len(dates) >= 1: row[1] = dates[0]
    if len(dates) >= 2: row[2] = dates[1]
    if len(dates) >= 3: row[3] = dates[2]

    # ---------- STATUS ----------
    if re.search(r'Termin[a-z]*', line, re.I):
        row[7] = "Terminated"
    elif re.search(r'Active', line, re.I):
        row[7] = "Active"

    # ---------- DECIMALS ----------
    if len(decimals) >= 1: row[8] = decimals[0]
    if len(decimals) >= 2: row[9] = decimals[1]
    if len(decimals) >= 3: row[10] = decimals[2]

    # ---------- AGES & COUNT (DOMAIN RULE APPLIED) ----------
    if row[3] and row[7]:
        try:
            start = line.index(row[3]) + len(row[3])
            end = line.lower().index(row[7].lower())
            block = line[start:end]
            nums = re.findall(r'\b\d+\b', block)

            if len(nums) == 3:
                row[4], row[5], row[6] = nums
            elif len(nums) == 2:
                row[4], row[6] = nums
                row[5] = None
        except ValueError:
            pass

    # ---------- FLAGS ----------
    flags = re.findall(r'\b[A-Z]\b', line.upper())
    if len(flags) >= 1: row[11] = flags[0]
    if len(flags) >= 2: row[12] = flags[1]
    if len(flags) >= 3: row[13] = flags[2]

    # ---------- ARM PRODUCT ----------
    arm_match = re.search(r'\b\d+[A-Z]\b', line)
    row[14] = arm_match.group(0) if arm_match else None

    # ---------- MAX CLAIM & PRINCIPAL ----------
    large_nums = [n for n in numbers if len(n) > 3]

    if len(large_nums) >= 1:
        row[15] = large_nums[0]      # max_clm_amt
    if len(large_nums) >= 2:
        row[16] = large_nums[1]      # init_prncpl_lmt

    # ---------- FEES ----------
    row[17] = 0

    # ---------- ZIP & LOAN TYPE (RESTORED LOGIC) ----------
    if len(numbers) >= 2:
        row[19] = str(numbers[-1]).zfill(2)   # loan_typ
        row[18] = numbers[-2] if len(numbers[-2]) == 5 else None

    return row

# ---------- BUILD DATAFRAME ----------
lines = text.split('\n')
rows = [robust_parse(l) for l in lines if len(l.strip()) > 20]

df = pd.DataFrame(rows, columns=target_columns)

df.tail(30)
# Out:
#                                             lender  clsing_dt endrsmt_dt  \
# 35     ["PLAZA HOME MORTGAGE, INC.'   a/tovaoi0  3       None       None
# 36                  [WELLS FARGO BANK NA'   32010]   4/5/2010  5/16/2017
# 37                  ["BANK OF AMERICA NA CHARLOTTE  4/19/2010       None
# 38             ["PINANCTAL FREEDOM ACQUISITION LLC  3/19/2010       None
# 39                 [WELLS FARGO BANK NAY   aafaono  3/12/2010       None
# 40                [WELLS FARGO BANK NAT   a/ayaoi0       None       None
# 41                  ['BANK OF AMERICA NA cuaRLorTE  4/15/2010       None
# 42       [JAMES B NUTTER AND ComPaNY'   a/a6 2010]  2/12/2010       None
# 43                  ['BANK OF AMERICA NA CHARLOTTE       None       None
# 44                 [WELLS FARGO BANK NA   a/azaono       None       None
# 45      ['METLIFE BANK, NATIONAL Association'   a/       None       None
# 46    ["BANK OF AMERICA NA CHARLOTTE'   a/25 2010]       None       None
# 47                  ['BANK OF AMERICA NA CHARLOTTE  2/18/2010  3/16/2010
# 48              METLIFE BANK, NATIONAL ASSocraTION   2/6/2010  3/11/2010
# 49        GENERATION MORTGAGE Company'   a/tzyaoi0       None       None
# 50                                            None       None       None
# 51                [WELLS FARGO BANK NA'   aiz/2oi0  3/25/2010  9/15/2020
# 52           PLAZA HOME WORTGAGE, INC.'   a/azaono       None       None
# 53             ["PINANCTAL FREEDOM ACQUISITION LLC  3/17/2010   4/9/2010
# 54                      [TONE REVERSE MORTGAGE LLC  1/30/2010  3/12/2010
# 55                ["PINANCE OF AMERICA REVERSE LLC   4/2/2010       None
# 56  ["BANK OF AMERICA NA CHARLOTTE'   a/tovaoi0  3       None       None
# 57                    BANK OP AMERICA NA CHARLOTTE   5/7/2010  6/14/2010
# 58             ["MIDCONTINENT FINANCIAL CENTER INC   5/4/2010       None
# 59                    BANK OP AMERICA NA CHARLOTTE  3/25/2010   5/3/2010
# 60                                            None       None       None
# 61          [TFINANCE OF AWERTCA REVERSE LLC'   27  3/26/2010  12/9/2016
# 62                  ['WELLS FARGO BANK NAT a/aaoi0  3/23/2010       None
# 63                  ['BANK OF AMERICA NA CuARLOTTE   3/2/2010       None
# 64                         [ANTEC FUNDING GRouP Lc   5/5/2010       None
#
#      tmntn_dt Borr_Age Coborr_Age Borr_Cnt   es_status int_rt int_rt_10yr  \
# 35       None     None       None     None        None   5.56        None
# 36       None     None       None     None  Terminated   5.49        None
# 37       None     None       None     None  Terminated   5.56        None
# 38       None     None       None     None        None  2.482        None
# 39       None     None       None     None  Terminated   5.49        None
# 40       None     None       None     None        None   None        None
# 41       None     None       None     None        None  2.720        6.08
# 42       None     None       None     None  Terminated   None        None
# 43       None     None       None     None  Terminated   5.56         5.6
# 44       None     None       None     None        None   None        None
# 45       None     None       None     None        None   5.56         5.6
# 46       None     None       None     None        None   None        None
# 47  6/25/2013       85       None       83  Terminated   None        None
# 48       None     None       None     None  Terminated   None        None
# 49       None     None       None     None        None   5.56        5.56
# 50       None     None       None     None        None   None        None
# 51       None     None       None     None  Terminated  2.729    339646.5
# 52       None     None       None     None        None   None        None
# 53   9/2/2020     None       None     None  Terminated   5.56        5.56
# 54       None     None       None     None  Terminated   None        None
# 55       None     None       None     None        None   5.56        5.56
# 56       None     None       None     None        None   5.56        None
# 57   6/5/2019     None       None     None  Terminated   5.49        None
# 58       None     None       None     None        None   5.56        None
# 59       None     None       None     None  Terminated   5.56        None
# 60       None     None       None     None        None   None        None
# 61       None     None       None     None        None   5.56        5.56
# 62       None     None       None     None  Terminated   5.49        None
# 63       None     None       None     None  Terminated   6.25        None
# 64       None     None       None     None        None   None        None
#
#    hecm_margin pd_stmln_flg rt_typ arm_indx_typ arm_prdc_typ max_clm_amt  \
# 35        None            A   None         None         None        3660
# 36        None         None   None         None         None       32010
# 37        None         None   None         None         None       97420
# 38        None         None   None         None         None       00000
# 39        None            A      A         None         None       30000
# 40        None            A   None         None         None       97603
# 41        None         None   None         None         None        2010
# 42        None            B      A         None         None        2010
# 43        None            O      S         None         None        2010
# 44        None            A      A         None         None      310000
# 45        None            A   None         None         None        9715
# 46        None            A      A         None         None        2010
# 47        None         None   None         None         None      200000
# 48        None         None   None         None         None       20000
# 49        None            A   None         None         None      325000
# 50        None            A      P         None         None      327000
# 51        None            A   None         None         None      625500
# 52        None            A   None         None         None        7200
# 53        None            F   None         None         None       60000
# 54        None            I      E            F         None       97467
# 55        None         None   None         None         None      330000
# 56        None            A   None         None         None      525000
# 57        None         None   None         None         None       97753
# 58        None            A   None         None         None        2010
# 59        None         None   None         None         None        5000
# 60        None         None   None         None         None       60000
# 61        None         None   None         None         None        2719
# 62        None            A   None         None         None       54000
# 63        None         None   None         None         None        2010
# 64        None            P   None         None         None       30000
#
#    init_prncpl_lmt  hecm_orgntn_fees prop_addr_zip_cd loan_typ
# 35           97459                 0            97459       02
# 36            5000                 0            97138       02
# 37            None                 0            97420       02
# 38            None                 0             None    00000
# 39           97381                 0            97381       02
# 40            None                 0            97603       02
# 41           97071                 0            97071       02
# 42           37000                 0            97386       02
# 43            5000                 0             None       02
# 44           97064                 0            97064       02
# 45            None                 0             None       02
# 46            None                 0             None       02
# 47          136200                 0             None       02
# 48           97236                 0            97236       02
# 49           97470                 0            97470       02
# 50           97401                 0            97401       02
# 51            None                 0             None     None
# 52          260000                 0            97401       02
# 53           43000                 0            43000    97707
# 54            None                 0            97467       02
# 55            5460                 0             None    97223
# 56           97301                 0            97301       02
# 57            None                 0            97753       02
# 58           97835                 0            97835       02
# 59           04775                 0            97423       02
# 60            3200                 0            97527       02
# 61            2010                 0            97471       02
# 62        92092080                 0            97266       02
# 63           97210                 0             None    97210
# 64            None                 0            30000       02

# %%
# %reset
# %whos function
# Out:
# No variables match your requested type.

# %% [markdown]
# # Final

# %%
input_file = r'C:\pdf2csv\extracted_files\recovered\22.pdf'

print("1. Converting PDF to Image...")
images = convert_from_path(input_file, first_page=1, last_page=1, poppler_path=poppler_bin_path)

print("2. Running OCR with Table Segmentation...")
# --psm 6 tells Tesseract to treat the image as a single uniform block of text
custom_config = r'--oem 3 --psm 6'
text = pytesseract.image_to_string(images[0], config=custom_config)

target_columns = [
    'lender', 'clsing_dt', 'endrsmt_dt', 'tmntn_dt', 'Borr_Age', 
    'Coborr_Age', 'Borr_Cnt', 'es_status', 'int_rt', 'int_rt_10yr', 
    'hecm_margin', 'pd_stmln_flg', 'rt_typ', 'arm_indx_typ', 
    'arm_prdc_typ', 'max_clm_amt', 'init_prncpl_lmt', 
    'hecm_orgntn_fees', 'prop_addr_zip_cd', 'loan_typ'
]

def robust_parse(line):
    row = [None] * 20

    # ---------- OCR NORMALIZATION ----------
    line = (
        line.replace('”', '"')
            .replace("’", "'")
            .replace('!', '')
            .replace('|', ' ')
    )

    # ---------- PATTERN EXTRACTION ----------
    dates = re.findall(r'\d{1,2}/\d{1,2}/\d{2,4}', line)
    decimals = re.findall(r'\d+\.\d+', line)

    # Remove dates & decimals before integer parsing
    clean_text = re.sub(r'\d{1,2}/\d{1,2}/\d{2,4}', ' ', line)
    clean_text = re.sub(r'\d+\.\d+', ' ', clean_text)
    numbers = re.findall(r'\b\d+\b', clean_text)

    # ---------- LENDER ----------
    lender_match = re.search(r'^(.*?)(?=\d{1,2}/)', line)
    row[0] = lender_match.group(1).strip().strip('"').strip("'") if lender_match else None

    # ---------- DATES ----------
    if len(dates) >= 1: row[1] = dates[0]
    if len(dates) >= 2: row[2] = dates[1]
    if len(dates) >= 3: row[3] = dates[2]

    # ---------- STATUS ----------
    if re.search(r'Termin[a-z]*', line, re.I):
        row[7] = "Terminated"
    elif re.search(r'Active', line, re.I):
        row[7] = "Active"

    # ---------- DECIMALS ----------
    if len(decimals) >= 1: row[8] = decimals[0]
    if len(decimals) >= 2: row[9] = decimals[1]
    if len(decimals) >= 3: row[10] = decimals[2]

    # ---------- AGES & COUNT (DOMAIN RULE APPLIED) ----------
    if row[3] and row[7]:
        try:
            start = line.index(row[3]) + len(row[3])
            end = line.lower().index(row[7].lower())
            block = line[start:end]
            nums = re.findall(r'\b\d+\b', block)

            if len(nums) == 3:
                row[4], row[5], row[6] = nums
            elif len(nums) == 2:
                row[4], row[6] = nums
                row[5] = None
        except ValueError:
            pass

    # ---------- FLAGS ----------
    flags = re.findall(r'\b[A-Z]\b', line.upper())
    if len(flags) >= 1: row[11] = flags[0]
    if len(flags) >= 2: row[12] = flags[1]
    if len(flags) >= 3: row[13] = flags[2]

    # ---------- ARM PRODUCT ----------
    arm_match = re.search(r'\b\d+[A-Z]\b', line)
    row[14] = arm_match.group(0) if arm_match else None

    # ---------- MAX CLAIM & PRINCIPAL ----------
    large_nums = [n for n in numbers if len(n) > 3]

    if len(large_nums) >= 1:
        row[15] = large_nums[0]      # max_clm_amt
    if len(large_nums) >= 2:
        row[16] = large_nums[1]      # init_prncpl_lmt

    # ---------- FEES ----------
    row[17] = 0

    # ---------- ZIP & LOAN TYPE (RESTORED LOGIC) ----------
    if len(numbers) >= 2:
        row[19] = str(numbers[-1]).zfill(2)   # loan_typ
        row[18] = numbers[-2] if len(numbers[-2]) == 5 else None

    return row

# ---------- BUILD DATAFRAME ----------
lines = text.split('\n')
rows = [robust_parse(l) for l in lines if len(l.strip()) > 20]

df = pd.DataFrame(rows, columns=target_columns)

# %%
input_file = r'C:\pdf2csv\extracted_files\recovered\22.pdf'

print("1. Converting PDF to Image...")
images = convert_from_path(input_file, first_page=1, last_page=1, poppler_path=poppler_bin_path)

print("2. Running OCR with Table Segmentation...")
# --psm 6 tells Tesseract to treat the image as a single uniform block of text
custom_config = r'--oem 3 --psm 6'
text = pytesseract.image_to_string(images[0], config=custom_config)

target_columns = [
    'lender', 'clsing_dt', 'endrsmt_dt', 'tmntn_dt', 'Borr_Age', 
    'Coborr_Age', 'Borr_Cnt', 'es_status', 'int_rt', 'int_rt_10yr', 
    'hecm_margin', 'pd_stmln_flg', 'rt_typ', 'arm_indx_typ', 
    'arm_prdc_typ', 'max_clm_amt', 'init_prncpl_lmt', 
    'hecm_orgntn_fees', 'prop_addr_zip_cd', 'loan_typ'
]

def robust_parse(line):
    row = [None] * 20

    # ---------- OCR NORMALIZATION ----------
    line = (
        line.replace('”', '"')
            .replace("’", "'")
            .replace('!', '')
            .replace('|', ' ')
    )

    # ---------- PATTERN EXTRACTION ----------
    dates = re.findall(r'\d{1,2}/\d{1,2}/\d{2,4}', line)
    decimals = re.findall(r'\d+\.\d+', line)

    # Remove dates & decimals before integer parsing
    clean_text = re.sub(r'\d{1,2}/\d{1,2}/\d{2,4}', ' ', line)
    clean_text = re.sub(r'\d+\.\d+', ' ', clean_text)
    numbers = re.findall(r'\b\d+\b', clean_text)

    # ---------- LENDER ----------
    lender_match = re.search(r'^(.*?)(?=\d{1,2}/)', line)
    row[0] = lender_match.group(1).strip().strip('"').strip("'") if lender_match else None

    # ---------- DATES ----------
    if len(dates) >= 1: row[1] = dates[0]
    if len(dates) >= 2: row[2] = dates[1]
    if len(dates) >= 3: row[3] = dates[2]

    # ---------- STATUS ----------
    if re.search(r'Termin[a-z]*', line, re.I):
        row[7] = "Terminated"
    elif re.search(r'Active', line, re.I):
        row[7] = "Active"

    # ---------- DECIMALS ----------
    if len(decimals) >= 1: row[8] = decimals[0]
    if len(decimals) >= 2: row[9] = decimals[1]
    if len(decimals) >= 3: row[10] = decimals[2]

    # ---------- AGES & COUNT (DOMAIN RULE APPLIED) ----------
    if row[3] and row[7]:
        try:
            start = line.index(row[3]) + len(row[3])
            end = line.lower().index(row[7].lower())
            block = line[start:end]
            nums = re.findall(r'\b\d+\b', block)

            if len(nums) == 3:
                row[4], row[5], row[6] = nums
            elif len(nums) == 2:
                row[4], row[6] = nums
                row[5] = None
        except ValueError:
            pass

    # ---------- FLAGS ----------
    flags = re.findall(r'\b[A-Z]\b', line.upper())
    if len(flags) >= 1: row[11] = flags[0]
    if len(flags) >= 2: row[12] = flags[1]
    if len(flags) >= 3: row[13] = flags[2]

    # ---------- ARM PRODUCT ----------
    arm_match = re.search(r'\b\d+[A-Z]\b', line)
    row[14] = arm_match.group(0) if arm_match else None

    # ---------- MAX CLAIM & PRINCIPAL ----------
    large_nums = [n for n in numbers if len(n) > 3]

    if len(large_nums) >= 1:
        row[15] = large_nums[0]      # max_clm_amt
    if len(large_nums) >= 2:
        row[16] = large_nums[1]      # init_prncpl_lmt

    # ---------- FEES ----------
    row[17] = 0

    # ---------- ZIP & LOAN TYPE (RESTORED LOGIC) ----------
    if len(numbers) >= 2:
        row[19] = str(numbers[-1]).zfill(2)   # loan_typ
        row[18] = numbers[-2] if len(numbers[-2]) == 5 else None

    return row

# ---------- BUILD DATAFRAME ----------
lines = text.split('\n')
rows = [robust_parse(l) for l in lines if len(l.strip()) > 20]

df = pd.DataFrame(rows, columns=target_columns)

# ---------- ADD SOURCE METADATA COLUMNS ----------
source_pdf = input_file.split('\\')[-1].replace('.pdf', '')
df.insert(0, 'row_in_pdf', range(1, len(df) + 1))
df.insert(0, 'source_pdf', source_pdf)

df
# Out:
# 1. Converting PDF to Image...
# 2. Running OCR with Table Segmentation...
#    source_pdf  row_in_pdf                                 lender  clsing_dt  \
# 0          22           1              “JAMES NUTTER AND COMPANY  6/15/2007
# 1          22           2            “JAMES B NUTTER AND COMPANY  6/19/2007
# 2          22           3                    WELLS FARGO BANK NA  8/21/2007
# 3          22           4           PACIFIC REVERSE MORTGAGE INC  1/18/2007
# 4          22           5                    WELLS FARGO BANK NA  6/25/2007
# ..        ...         ...                                    ...        ...
# 73         22          74  BINANCIAL FREEDOM SENIOR FUNDING CORP  9/28/2007
# 74         22          75  FINANCIAL FREEDOM SENIOR FUNDING CORP  8/20/2007
# 75         22          76             JAMES B NUTTER AND COMPANY   8/3/2007
# 76         22          77            “JAMES B_NUTTER AND COMPANY   8/6/2007
# 77         22          78           BANK OF AMERICA NA CHARLOTTE  9/26/2007
#
#     endrsmt_dt    tmntn_dt Borr_Age Coborr_Age Borr_Cnt   es_status  ...  \
# 0    7/27/2007   4/21/2016       73       None        1  Terminated  ...
# 1    7/24/2007    4/6/2009       98       None        1  Terminated  ...
# 2   11/20/2007   11/4/2019       72       None        1  Terminated  ...
# 3    8/10/2007  10/29/2008     None       None     None  Terminated  ...
# 4    7/18/2007        None     None       None     None        None  ...
# ..         ...         ...      ...        ...      ...         ...  ...
# 73  10/25/2007        None     None       None     None        None  ...
# 74   9/24/2007        None     None       None     None        None  ...
# 75  10/17/2007        None     None       None     None        None  ...
# 76  10/17/2007        None     None       None     None        None  ...
# 77  11/29/2007   2/26/2020        2       None        1  Terminated  ...
#
#    hecm_margin pd_stmln_flg rt_typ arm_indx_typ arm_prdc_typ max_clm_amt  \
# 0         None            T   None         None         None       88000
# 1         None            B      T         None         None      108000
# 2         None            V   None         None         None      200000
# 3          1.5            U      N            T         None      130000
# 4         None            T      Y         None         None      200160
# ..         ...          ...    ...          ...          ...         ...
# 73        None            T   None         None         None       42000
# 74        1.03            N      T         None         None      162000
# 75         1.5            B      N            T         None       96000
# 76         1.5            T   None         None         None       75000
# 77        None            T   None         None         None      200160
#
#    init_prncpl_lmt hecm_orgntn_fees prop_addr_zip_cd  loan_typ
# 0            60808                0            35005        02
# 1            96444                0            36037        02
# 2           138200                0             None        02
# 3            85410                0            85410        02
# 4           122898                0             None        02
# ..             ...              ...              ...       ...
# 73           27678                0            35221        02
# 74          105462                0            36305        02
# 75           55872                0            36467        02
# 76           41325                0             None        02
# 77          123698                0            36532        02
#
# [78 rows x 22 columns]

# %% [markdown]
# # Loop

# %%
# ===================== CONFIG =====================
PDF_DIR = r'C:\pdf2csv\extracted_files\recovered'
CHECKPOINT_FILE = r'C:\pdf2csv\checkpoint.pkl'
CHECKPOINT_EVERY = 100
WORKERS = max(mp.cpu_count() - 1, 1)

# ===================== COLUMNS =====================
target_columns = [
    'source_pdf', 'row_in_pdf',
    'lender', 'clsing_dt', 'endrsmt_dt', 'tmntn_dt', 'Borr_Age',
    'Coborr_Age', 'Borr_Cnt', 'es_status', 'int_rt', 'int_rt_10yr',
    'hecm_margin', 'pd_stmln_flg', 'rt_typ', 'arm_indx_typ',
    'arm_prdc_typ', 'max_clm_amt', 'init_prncpl_lmt',
    'hecm_orgntn_fees', 'prop_addr_zip_cd', 'loan_typ'
]

# ===================== PARSER (UNCHANGED) =====================
def robust_parse(line):
    row = [None] * 20

    line = (
        line.replace('”', '"')
            .replace("’", "'")
            .replace('!', '')
            .replace('|', ' ')
    )

    dates = re.findall(r'\d{1,2}/\d{1,2}/\d{2,4}', line)
    decimals = re.findall(r'\d+\.\d+', line)

    clean_text = re.sub(r'\d{1,2}/\d{1,2}/\d{2,4}', ' ', line)
    clean_text = re.sub(r'\d+\.\d+', ' ', clean_text)
    numbers = re.findall(r'\b\d+\b', clean_text)

    lender_match = re.search(r'^(.*?)(?=\d{1,2}/)', line)
    row[0] = lender_match.group(1).strip().strip('"').strip("'") if lender_match else None

    if len(dates) >= 1: row[1] = dates[0]
    if len(dates) >= 2: row[2] = dates[1]
    if len(dates) >= 3: row[3] = dates[2]

    if re.search(r'Termin[a-z]*', line, re.I):
        row[7] = "Terminated"
    elif re.search(r'Active', line, re.I):
        row[7] = "Active"

    if len(decimals) >= 1: row[8] = decimals[0]
    if len(decimals) >= 2: row[9] = decimals[1]
    if len(decimals) >= 3: row[10] = decimals[2]

    if row[3] and row[7]:
        try:
            start = line.index(row[3]) + len(row[3])
            end = line.lower().index(row[7].lower())
            nums = re.findall(r'\b\d+\b', line[start:end])
            if len(nums) == 3:
                row[4], row[5], row[6] = nums
            elif len(nums) == 2:
                row[4], row[6] = nums
        except ValueError:
            pass

    flags = re.findall(r'\b[A-Z]\b', line.upper())
    if len(flags) >= 1: row[11] = flags[0]
    if len(flags) >= 2: row[12] = flags[1]
    if len(flags) >= 3: row[13] = flags[2]

    arm_match = re.search(r'\b\d+[A-Z]\b', line)
    row[14] = arm_match.group(0) if arm_match else None

    large_nums = [n for n in numbers if len(n) > 3]
    if len(large_nums) >= 1: row[15] = large_nums[0]
    if len(large_nums) >= 2: row[16] = large_nums[1]

    row[17] = 0

    if len(numbers) >= 2:
        row[19] = str(numbers[-1]).zfill(2)
        row[18] = numbers[-2] if len(numbers[-2]) == 5 else None

    return row

# ===================== TEXT EXTRACTION =====================
def extract_text(pdf_path):
    try:
        import pdfplumber
        with pdfplumber.open(pdf_path) as pdf:
            text = pdf.pages[0].extract_text()
            if text and len(text.strip()) > 50:
                return text
    except Exception:
        pass

    images = convert_from_path(pdf_path, first_page=1, last_page=1, poppler_path=poppler_bin_path)
    return pytesseract.image_to_string(images[0], config='--oem 3 --psm 6')

# ===================== FILE PROCESSOR =====================
def process_pdf(pdf_path):
    try:
        text = extract_text(pdf_path)
        lines = [l for l in text.split('\n') if len(l.strip()) > 20]
        pdf_name = os.path.basename(pdf_path).replace('.pdf', '')

        rows = []
        for i, line in enumerate(lines, start=1):
            parsed = robust_parse(line)
            rows.append([pdf_name, i] + parsed)

        return rows

    except Exception as e:
        print(f"FAILED: {pdf_path} -> {e}")
        return []

# ===================== CHECKPOINT =====================
def load_checkpoint():
    if os.path.exists(CHECKPOINT_FILE):
        with open(CHECKPOINT_FILE, 'rb') as f:
            return pickle.load(f)
    return set(), []

def save_checkpoint(done_files, all_rows):
    with open(CHECKPOINT_FILE, 'wb') as f:
        pickle.dump((done_files, all_rows), f)

# ===================== MAIN =====================
if __name__ == '__main__':
    pdf_files = glob.glob(os.path.join(PDF_DIR, '*.pdf'))
    done_files, all_rows = load_checkpoint()

    remaining = [p for p in pdf_files if p not in done_files]
    print(f"Remaining PDFs: {len(remaining)}")

    pool = mp.Pool(WORKERS)

    for idx, result in enumerate(pool.imap_unordered(process_pdf, remaining), 1):
        pdf_path = remaining[idx - 1]
        done_files.add(pdf_path)
        all_rows.extend(result)

        if idx % CHECKPOINT_EVERY == 0:
            save_checkpoint(done_files, all_rows)
            print(f"Checkpoint saved at {idx} files")

    pool.close()
    pool.join()

    save_checkpoint(done_files, all_rows)

    master_df = pd.DataFrame(all_rows, columns=target_columns)
# Out:
# Remaining PDFs: 13764
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[118], line 134
#     131 remaining = [p for p in pdf_files if p not in done_files]
#     132 print(f"Remaining PDFs: {len(remaining)}")
# --> 134 pool = mp.Pool(WORKERS)
#     136 for idx, result in enumerate(pool.imap_unordered(process_pdf, remaining), 1):
#     137     pdf_path = remaining[idx - 1]
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\context.py:119, in BaseContext.Pool(self, processes, initializer, initargs, maxtasksperchild)
#     117 '''Returns a process pool object'''
#     118 from .pool import Pool
# --> 119 return Pool(processes, initializer, initargs, maxtasksperchild,
#     120             context=self.get_context())
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\pool.py:215, in Pool.__init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     213 self._processes = processes
#     214 try:
# --> 215     self._repopulate_pool()
#     216 except Exception:
#     217     for p in self._pool:
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\pool.py:306, in Pool._repopulate_pool(self)
#     305 def _repopulate_pool(self):
# --> 306     return self._repopulate_pool_static(self._ctx, self.Process,
#     307                                         self._processes,
#     308                                         self._pool, self._inqueue,
#     309                                         self._outqueue, self._initializer,
#     310                                         self._initargs,
#     311                                         self._maxtasksperchild,
#     312                                         self._wrap_exception)
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\pool.py:329, in Pool._repopulate_pool_static(ctx, Process, processes, pool, inqueue, outqueue, initializer, initargs, maxtasksperchild, wrap_exception)
#     327 w.name = w.name.replace('Process', 'PoolWorker')
#     328 w.daemon = True
# --> 329 w.start()
#     330 pool.append(w)
#     331 util.debug('added worker')
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\context.py:337, in SpawnProcess._Popen(process_obj)
#     334 @staticmethod
#     335 def _Popen(process_obj):
#     336     from .popen_spawn_win32 import Popen
# --> 337     return Popen(process_obj)
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\popen_spawn_win32.py:45, in Popen.__init__(self, process_obj)
#      44 def __init__(self, process_obj):
# ---> 45     prep_data = spawn.get_preparation_data(process_obj._name)
#      47     # read end of pipe will be duplicated by the child process
#      48     # -- see spawn_main() in spawn.py.
#      49     #
#      50     # bpo-33929: Previously, the read end of pipe was "stolen" by the child
#      51     # process, but it leaked a handle if the child process had been
#      52     # terminated before it could steal the handle from the parent process.
#      53     rhandle, whandle = _winapi.CreatePipe(None, 0)
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\spawn.py:193, in get_preparation_data(name)
#     190 # Figure out whether to initialise main in the subprocess as a module
#     191 # or through direct execution (or to leave it alone entirely)
#     192 main_module = sys.modules['__main__']
# --> 193 main_mod_name = getattr(main_module.__spec__, "name", None)
#     194 if main_mod_name is not None:
#     195     d['init_main_from_name'] = main_mod_name
#
# AttributeError: module '__main__' has no attribute '__spec__'

# %% [markdown]
# # PostProcessing

# %%
final_df = pd.read_csv('master_output.csv')
final_df
# Out:
#         source_pdf  row_in_pdf                                  lender  \
# 0              100           1                                GMFS LLC
# 1              100           2                ONE REVERSE MORTGAGE LLC
# 2              100           3                SUN WEST MORTGAGE CO_INC
# 3              100           4                  “MSR_ASSET VEHICLE LLC
# 4              100           5                SUN WEST MORTGAGE CO_TNC
# ...            ...         ...                                     ...
# 964660        6852          61                                     NaN
# 964661        6852          62  [TFINANCE OF AWERTCA REVERSE LLC'   27
# 964662        6852          63          ['WELLS FARGO BANK NAT a/aaoi0
# 964663        6852          64          ['BANK OF AMERICA NA CuARLOTTE
# 964664        6852          65                 [ANTEC FUNDING GRouP Lc
#
#          clsing_dt endrsmt_dt   tmntn_dt  Borr_Age  Coborr_Age  Borr_Cnt  \
# 0       12/31/2012  2/25/2013  2/16/2017      64.0         NaN       1.0
# 1       12/15/2012  1/25/2013        NaN       NaN         NaN       NaN
# 2        1/11/2013   3/4/2013        NaN       NaN         NaN       NaN
# 3        2/20/2013  7/25/2013        NaN       NaN         NaN       NaN
# 4        1/26/2013  4/22/2013        NaN       NaN         NaN       NaN
# ...            ...        ...        ...       ...         ...       ...
# 964660         NaN        NaN        NaN       NaN         NaN       NaN
# 964661   3/26/2010  12/9/2016        NaN       NaN         NaN       NaN
# 964662   3/23/2010        NaN        NaN       NaN         NaN       NaN
# 964663    3/2/2010        NaN        NaN       NaN         NaN       NaN
# 964664    5/5/2010        NaN        NaN       NaN         NaN       NaN
#
#          es_status  int_rt  int_rt_10yr  hecm_margin pd_stmln_flg rt_typ  \
# 0       Terminated    5.06         5.06          NaN          NaN    NaN
# 1              NaN    4.50         4.50          NaN            O      N
# 2              NaN    5.30         5.30          NaN            I      I
# 3              NaN    5.06         5.06          NaN            O    NaN
# 4              NaN    4.99          NaN          NaN          NaN    NaN
# ...            ...     ...          ...          ...          ...    ...
# 964660         NaN     NaN          NaN          NaN          NaN    NaN
# 964661         NaN    5.56         5.56          NaN          NaN    NaN
# 964662  Terminated    5.49          NaN          NaN            A    NaN
# 964663  Terminated    6.25          NaN          NaN          NaN    NaN
# 964664         NaN     NaN          NaN          NaN            P    NaN
#
#        arm_indx_typ arm_prdc_typ  max_clm_amt  init_prncpl_lmt  \
# 0               NaN          NaN     117000.0          74529.0
# 1                 R          NaN     200000.0         136200.0
# 2                 A          NaN     130000.0          86710.0
# 3               NaN          NaN     300000.0         207900.0
# 4               NaN          NaN     240000.0         161040.0
# ...             ...          ...          ...              ...
# 964660          NaN          NaN      60000.0           3200.0
# 964661          NaN          NaN       2719.0           2010.0
# 964662          NaN          NaN      54000.0       92092080.0
# 964663          NaN          NaN       2010.0          97210.0
# 964664          NaN          NaN      30000.0              NaN
#
#         hecm_orgntn_fees  prop_addr_zip_cd  loan_typ
# 0                      0           36108.0       2.0
# 1                      0           36312.0       2.0
# 2                      0           36571.0       2.0
# 3                      0           36078.0       2.0
# 4                      0           35966.0       2.0
# ...                  ...               ...       ...
# 964660                 0           97527.0       2.0
# 964661                 0           97471.0       2.0
# 964662                 0           97266.0       2.0
# 964663                 0               NaN   97210.0
# 964664                 0           30000.0       2.0
#
# [964665 rows x 22 columns]

# %%
final_df.isnull().sum()
# Out:
# source_pdf               0
# row_in_pdf               0
# lender               16976
# clsing_dt            56336
# endrsmt_dt          109649
# tmntn_dt            535282
# Borr_Age            643621
# Coborr_Age          881008
# Borr_Cnt            643621
# es_status           479483
# int_rt              100557
# int_rt_10yr         244402
# hecm_margin         607678
# pd_stmln_flg        124288
# rt_typ              384086
# arm_indx_typ        771189
# arm_prdc_typ        952770
# max_clm_amt          30115
# init_prncpl_lmt      95515
# hecm_orgntn_fees         0
# prop_addr_zip_cd    208924
# loan_typ             12648
# dtype: int64

# %%
# Ensure lender is string (in case of NaNs)
lender_str = final_df['lender'].astype(str)

# Create masks
endorsed_mask = (
    final_df['es_status'].isna() &
    lender_str.str.contains(r'endorsed', case=False, regex=True)
)

terminated_mask = (
    final_df['es_status'].isna() &
    lender_str.str.contains(r'terminated', case=False, regex=True)
)

# Assign values
final_df.loc[endorsed_mask, 'es_status'] = 'Endorsed'
final_df.loc[terminated_mask, 'es_status'] = 'Terminated'

# %%
# Sorts the DataFrame based on the length of the 'lender' column in descending order
final_df.sort_values(by='lender', key=lambda x: x.str.len(), ascending=False)
# Out:
#         source_pdf  row_in_pdf  \
# 59499        10798          60
# 14562        10193          11
# 876929        5671          31
# 65275        10877          29
# 42632        10570          33
# ...            ...         ...
# 964608        6852           9
# 964620        6852          21
# 964625        6852          26
# 964650        6852          51
# 964660        6852          61
#
#                                                    lender clsing_dt  \
# 59499   [GENERATION MORTGAGE ComPANY'   a/ayaoial a/ii...       NaN
# 14562   [METLIFE BANK, NATIONAL Assocration'   a/avaou...       NaN
# 876929  NATLONNIDE EQUITIES CoRPoRATION'   go/ov2o14] ...       NaN
# 65275   ['REVERSE MORTGAGE FUNDING LLC'   t2tay20i7  i...       NaN
# 42632   [FINANCIAL FREEDOM SENIOR FUNDING Corp' ___ _t...       NaN
# ...                                                   ...       ...
# 964608                                                NaN       NaN
# 964620                                                NaN       NaN
# 964625                                                NaN       NaN
# 964650                                                NaN       NaN
# 964660                                                NaN       NaN
#
#        endrsmt_dt tmntn_dt  Borr_Age  Coborr_Age  Borr_Cnt   es_status  \
# 59499         NaN      NaN       NaN         NaN       NaN  Terminated
# 14562         NaN      NaN       NaN         NaN       NaN  Terminated
# 876929        NaN      NaN       NaN         NaN       NaN    Endorsed
# 65275         NaN      NaN       NaN         NaN       NaN  Terminated
# 42632         NaN      NaN       NaN         NaN       NaN  Terminated
# ...           ...      ...       ...         ...       ...         ...
# 964608        NaN      NaN       NaN         NaN       NaN         NaN
# 964620        NaN      NaN       NaN         NaN       NaN         NaN
# 964625        NaN      NaN       NaN         NaN       NaN         NaN
# 964650        NaN      NaN       NaN         NaN       NaN         NaN
# 964660        NaN      NaN       NaN         NaN       NaN         NaN
#
#         int_rt  int_rt_10yr  hecm_margin pd_stmln_flg rt_typ arm_indx_typ  \
# 59499    2.204          NaN          NaN            A      A            A
# 14562    5.030          NaN          NaN            A      I          NaN
# 876929   2.903          NaN          NaN            G      A          NaN
# 65275    4.886          NaN          NaN            I      A            A
# 42632      NaN          NaN          NaN            E      A            A
# ...        ...          ...          ...          ...    ...          ...
# 964608   5.560         5.56          NaN            S    NaN          NaN
# 964620   3.495          NaN          NaN            S    NaN          NaN
# 964625     NaN          NaN          NaN            A      T            A
# 964650     NaN          NaN          NaN            A      P          NaN
# 964660     NaN          NaN          NaN          NaN    NaN          NaN
#
#        arm_prdc_typ  max_clm_amt  init_prncpl_lmt  hecm_orgntn_fees  \
# 59499           NaN       4805.0         575000.0                 0
# 14562           NaN      90000.0          23452.0                 0
# 876929          NaN     565000.0          64425.0                 0
# 65275           NaN      98022.0              NaN                 0
# 42632           NaN       2007.0           2007.0                 0
# ...             ...          ...              ...               ...
# 964608          NaN      97816.0              NaN                 0
# 964620          NaN          NaN              NaN                 0
# 964625          NaN       2979.0          28000.0                 0
# 964650          NaN     327000.0          97401.0                 0
# 964660          NaN      60000.0           3200.0                 0
#
#         prop_addr_zip_cd  loan_typ
# 59499                NaN       2.0
# 14562            23452.0       2.0
# 876929               NaN    1762.0
# 65275            98022.0       2.0
# 42632            98270.0       2.0
# ...                  ...       ...
# 964608               NaN   97816.0
# 964620               NaN       2.0
# 964625           97230.0       2.0
# 964650           97401.0       2.0
# 964660           97527.0       2.0
#
# [964665 rows x 22 columns]

# %%
list(final_df['lender'])[0]
# Out:
# '[GENERATION MORTGAGE ComPANY\'   a/ayaoial a/ii/aoia a/a/goni  ta 75]   "Terminated\'   2.204] 4805] as [nh tw ams 575000] 33z925[ 37'

# %%
final_df.columns
# Out:
# Index(['source_pdf', 'row_in_pdf', 'lender', 'clsing_dt', 'endrsmt_dt',
#        'tmntn_dt', 'Borr_Age', 'Coborr_Age', 'Borr_Cnt', 'es_status', 'int_rt',
#        'int_rt_10yr', 'hecm_margin', 'pd_stmln_flg', 'rt_typ', 'arm_indx_typ',
#        'arm_prdc_typ', 'max_clm_amt', 'init_prncpl_lmt', 'hecm_orgntn_fees',
#        'prop_addr_zip_cd', 'loan_typ'],
#       dtype='object')

# %% [markdown]
# ## Lender

# %%
# Total non unique values in the column lender
final_df['lender'].nunique(dropna=False)
# Out:
# 48399

# %%
# Remove all the special characters and spaces from the beginning or the end
final_df['lender'] = final_df['lender'].str.replace(r'^[^a-zA-Z0-9]+|[^a-zA-Z0-9]+$', '', regex=True)

# %%
final_df['lender'].nunique(dropna=False)
# Out:
# 42787

# %%
# Turn all the characters to UPPER STRING
final_df['lender'] = final_df['lender'].str.upper()

# %%
final_df['lender'].nunique(dropna=False)
# Out:
# 40299

# %% [markdown]
# ### Most Frequent

# %%
# Returns a Series where the index is the Lender and the value is the count
final_df['lender'].value_counts()
# Out:
# lender
# FINANCIAL FREEDOM SENIOR FUNDING CORP           142416
# WELLS FARGO BANK NA                             127062
# AMERICAN ADVISORS GROUP                          80479
# BANK OF AMERICA NA CHARLOTTE                     34905
# SEATTLE MORTGAGE COMPANY                         32436
#                                                  ...
# SUINIT FUNDING TNC                                   1
# J_AND_R LENDING                                      1
# GENERATION MORTGAGE COWPANY'   @/TDOOIZ              1
# MOVEMENT WORTGAGE LLC'   5 /A/O0I2                   1
# BANK OF AMERICA NA CHARLOTTE'   A/TOVAOI0  3         1
# Name: count, Length: 29765, dtype: int64

# %% [markdown]
# #### WELLS FARGO BANK NA

# %%
# Returns unique values that contain a particular string
# 1. Define your search variable
search_string = "FARGO"

# 2. Filter the column and get unique values
# na=False handles rows with missing data so the code doesn't error out
list(final_df[final_df['lender'].str.contains(search_string, na=False)]['lender'].unique())

# %%
# Use .loc to find rows where 'lender' contains 'GMFS' and update the 'lender' column
final_df.loc[final_df['lender'].str.contains('FARGO BANK', na=False), 'lender'] = 'WELLS FARGO BANK NA'

# %%
final_df['lender'].nunique(dropna=False)
# Out:
# 35206

# %% [markdown]
# #### AMERICAN ADVISORS GROUP

# %%
# Returns unique values that contain a particular string
# 1. Define your search variable
search_string = "ADVISORS"

# 2. Filter the column and get unique values
# na=False handles rows with missing data so the code doesn't error out
list(final_df[final_df['lender'].str.contains(search_string, na=False)]['lender'].unique())
# Out:
# ['AMERICAN ADVISORS GROUP',
#  'AMERICAN ADVISORS GROUP\'   A/TAZYAONO] GENNI]   WA]   NDORSED "  5.625] 5.625] ANY TE G60',
#  "AMERICAN ADVISORS GROUP'   A/TZAON0",
#  'TAMERICAN ADVISORS GROUP™   87',
#  "AMERICAN ADVISORS GROUP' _   2010",
#  "AMERICAN ADVISORS GROUP'   T0IGY20N0",
#  'TAMBRICAN ADVISORS GROUP',
#  "TAMERICAN ADVISORS GROUP'   2Z/2Z0NN",
#  "AMERICAN ADVISORS GROUP'   TI2Z0NI",
#  "AMERICAN ADVISORS GROUP'   AON",
#  "TAMERICAN ADVISORS GROUP'   A",
#  'TAMERICAN ADVISORS GROUP   87',
#  "AMERICAN ADVISORS GROUP'   A5 FO0NI",
#  "AMERICAN ADVISORS GROUP'   A/ZA0NI",
#  'TAMERICAN ADVISORS GROUP AVZI/AONN',
#  "AMERICAN ADVISORS GROUP' 5 /TFA0NI",
#  "AMERICAN ADVISORS GROUP'   AZAR",
#  "AMERICAN ADVISORS GROUP'   A/ZZ/A0NI  5 /A",
#  "AMERICAN ADVISORS GROUP'   W",
#  'TAMERICAN ADVISORS GROUT   Z',
#  "AMERICAN ADVISORS GROUP' 6A FO0NI",
#  "AMERICAN ADVISORS GROUP'   ATIZ0NI",
#  'TAMERICAN ADVISORS GROUP',
#  "AMERICAN ADVISORS GROUP' _   G4Y2OUI  G/A",
#  'AMERICAN ADVISORS GROUT',
#  "AMERICAN ADVISORS GROUP'   AA",
#  'AMERICAN ADVISORS GROUPY',
#  'TAMERICAN ADVISORS GROUP 97',
#  "AMERICAN ADVISORS GROUP' _   AA /TOY2OUI",
#  'TAMERICAN ADVISORS GROUP 17',
#  "AMERICAN ADVISORS GROUP'   AZN] T",
#  "AMERICAN ADVISORS GROUP'   T",
#  "AMERICAN ADVISORS GROUP'   AZ/OZOUN  A/ASVAOUZ   ]   ASSIGNED '   5.06) 5.06] OFT TH T50",
#  "AMERICAN ADVISORS GROUP'   AZ/ZAY2OUI",
#  "AMERICAN ADVISORS GROUP' AZN",
#  "TAMERICAN ADVISORS GROUP'   I",
#  "AMERICAN ADVISORS GROUP' __   AZ/ZIYAOUI",
#  "AMERICAN ADVISORS GROUP'   AA/EZOONI",
#  "TAMERICAN ADVISORS GROUP'   ZVTOY20IN  2VE/AOIZ   ] 3] ASSIGNED '   5.06) 5.06] OFT 3 350",
#  "AMERICAN ADVISORS GROUP'   ATYAZ0IZ",
#  "AMERICAN ADVISORS GROUP'   AZ/IG/AONI",
#  "AMERICAN ADVISORS GROUP'   FAMI",
#  "AMERICAN ADVISORS GROUP'   A5 /2012",
#  "AMERICAN ADVISORS GROUP'   TZ0I2  S/IG/EOUZ    5]   ASSIGNED ‘  5.06) 5.06] OTT TE 90",
#  "TAMERICAN ADVISORS GROUP'   2YA0I2",
#  "AMERICAN ADVISORS GROUP' AZO",
#  "AMERICAN ADVISORS GROUP'   882012",
#  "AMERICAN ADVISORS GROUP'   A",
#  "AMERICAN ADVISORS GROUP'   TT/A0UZ",
#  "AMERICAN ADVISORS GROUP'   AA /A0IZ",
#  "TAMERICAN ADVISORS GROUP'   AZ",
#  'TAMERICAN ADVISORS GROUPT   8 /A/Z0I2',
#  "TAMERICAN ADVISORS GROUP'   AE",
#  "AMERICAN ADVISORS GROUP'   5A FA0NZ",
#  "AMERICAN ADVISORS GROUP'   Z",
#  "TAMERICAN ADVISORS GROUP'   2AOIE",
#  'TAMERICAN ADVISORS GROUP 87',
#  "TAMBRICAN ADVISORS GROUP'   AYANIA",
#  "TAMERICAN ADVISORS GROUP'   USFZ0IZ",
#  "AMERICAN ADVISORS GROUP'   ATAYAZ0IZ",
#  "TAMERICAN ADVISORS GROUP' 22012",
#  "TAMERICAN ADVISORS GROUP'   U20IE  TO/IZ/EOIZ  TEA] ASSIGNED @{ 5.06) 5.06 OTT 23500 ZZESI.5  _25",
#  "AMERICAN ADVISORS GROUP' AA /A",
#  'AMERICAN ADVISORS GROUT TOS FOOIZ   A/II/EOIS         ASSIGNED "  5.06] 06 FN TE SS0',
#  'TAMERICAN ADVISORS GROUPT 972172012',
#  'AMERICAN ADVISORS GOUP',
#  "TAMERICAN ADVISORS GROUP'   N0N20I2} _YA/EOIS}  ] 9] ASSIGNED '   5.06) 5.06] OFT 60",
#  "TAMERICAN ADVISORS GROUP' 2320S] S/APVAOIS}   TA] ASSIGNED   2.705) ASS] FUT AE T0",
#  "AMERICAN ADVISORS GROUP'   T0",
#  "AMERICAN ADVISORS GROUP'   FOO] 3",
#  "AMERICAN ADVISORS GROUP'   /A0IS",
#  'TAMERICAN ADVISORS GROUP™ 72012] I/IO/EOIS',
#  "TAMERICAN ADVISORS GROUP'   TAVAOIE  A/ESVEOIS}   TO] A] ASSIGNED '] AGO] AGO OFT TE Z900",
#  'TAMBRICAN ADVISORS GROUP   T/Z6YA0IA A/EAFAONST TEA] PA RNDORSED   EROS] AAN] FH A T600',
#  "TAMERICAN ADVISORS GROUP'   AUSYAOIE",
#  'AMERICAN ADVISORS GRUP',
#  "AMERICAN ADVISORS GROUP' _  G /2YA0I3",
#  "AMERICAN ADVISORS GROUP'   AN /A0I2",
#  "AMERICAN ADVISORS GROUP' TT /2012",
#  "AMERICAN ADVISORS GROUP'   AZ/TYAOI2",
#  "AMERICAN ADVISORS GROUP'   A2 OOIZ",
#  "AMERICAN ADVISORS GROUP'   AASO0IS",
#  "AMERICAN ADVISORS GROUP'   AZ/IGEOIZ",
#  "AMERICAN ADVISORS GROUP'   AZ/IGY2OI2",
#  "AMERICAN ADVISORS GROUP'   AZ/ZAOIZ",
#  "AMERICAN ADVISORS GROUP'   AA/Z",
#  "AMERICAN ADVISORS GROUP'   AE/ZFAORZ",
#  "AMERICAN ADVISORS GROUP'   A /2013",
#  "AMERICAN ADVISORS GROUP'   /FO0IS",
#  "AMERICAN ADVISORS GROUP'   A/Z",
#  "AMERICAN ADVISORS GROUP'   ATOAZ0IS",
#  "AMERICAN ADVISORS GROUP' __—  I AOIS",
#  "AMERICAN ADVISORS GROUP'   2A FO0IS",
#  "AMERICAN ADVISORS GROUP'   22013",
#  "TAMERICAN ADVISORS GROUP'   ZZOIS  S/AN/EOIS}_   3] TO] ASSIGNED '  AGO) AGO OTT TE Z00",
#  "AMERICAN ADVISORS GROUP' 2A FO0IS",
#  "AMERICAN ADVISORS GROUP'   AI /2013",
#  "AMERICAN ADVISORS GROUP'   AFTA",
#  "AMERICAN ADVISORS GROUP'   AZ /O0IS",
#  "TAMERICAN ADVISORS GROUP' 220I] AAS/AOIS}   TO] A] ASSIGNED   5.06) 5.06] OFT 30",
#  "AMERICAN ADVISORS GROUP'   A/20 2013",
#  "TAMERICAN ADVISORS GROUP' 5 /OYZOIS",
#  "AMERICAN ADVISORS GROUP' A5 /20I3",
#  "AMERICAN ADVISORS GROUP'   WTTYAZ0IS   G/IZ/2OIG}_   OF   ASSIGNED ‘  5.06] 5.06] ATH TA 50",
#  "AMERICAN ADVISORS GROUP'   AANG",
#  "AMERICAN ADVISORS GROUP'   AD FOONS",
#  "TAMERICAN ADVISORS GROUP'   TY20I3  OVA/AONS} WA}   TNDORSED 1] AGA) SSA] ES FUT AE T0",
#  'TAMERICAN ADVISORS GROUT A7 /A0IS',
#  "AMERICAN ADVISORS GROUP'   A/ZOOIS",
#  'TAMERICAN ADVISORS GROUP ANG /20I3',
#  "AMERICAN ADVISORS GROUP'   6AZ0IS  S/IA/AOIS}_   63]   ASSIGNED ‘  5.06) 5.06] OFT' TT 00",
#  "AMERICAN ADVISORS GROUP'   5 /2VAOIS",
#  'AMERICAN ADVISORS GROUT   A',
#  "TAMBRICAN ADVISORS GROUP   ZYOOIS  Z/AI/EONST   TA]   ASSIGNED '] 5.06) 5.06] FE AZ00",
#  "TAMERICAN ADVISORS GROUP'   T/2013",
#  'AMERICAN ADVISORS GROUP\' _—   GTYA0IS  TOVAI/ZOI3 _—       ENDORSED "  2.935] 62] 5 TEH YH NAS 20500] 283S5',
#  "TAMERICAN ADVISORS GROUP' 97",
#  'TAMERICAN ADVISORS GROUPT',
#  "TAMBRICAN ADVISORS GROUP'   A//20IS",
#  "TAMERICAN ADVISORS GROUP'   Z6A0IS",
#  'TAMERICAN ADVISORS GROUT',
#  "AMERICAN ADVISORS GROUP'   OIZ0IS  AZ/AA/EOIS}   TI] ASSIGNED '{3.I8) 52} TT TES T50",
#  "AMERICAN ADVISORS GROUP' _—   892013] TO/E",
#  "TAMERICAN ADVISORS GROUP'   82201",
#  "AMERICAN ADVISORS GROUP'   AOS",
#  'TAMERICAN ADVISORS GROUP   TZY20IS  TO/IP/AOIS}  E]    TINDORSED   2.935) 5.5] EV FT TAE Z000',
#  "TAMERICAN ADVISORS GROUP' AZ",
#  "AMERICAN ADVISORS GROUP'   FAA] /AO/Z0I4",
#  "TAMERICAN ADVISORS GROUP' A /20IS  AZ/EA/EOIS}   8]    ENDORSED §   3.73} 5.78] TNT TAE T650",
#  "AMERICAN ADVISORS GROUP' A /2ZA0IS",
#  "AMERICAN ADVISORS GROUP'  G 4A0I3",
#  "AMERICAN ADVISORS GROUP'   TO /ZVEZOIS",
#  "AMERICAN ADVISORS GROUP'   AA/AZYOOIS",
#  "AMERICAN ADVISORS GROUP'   07A /20I3",
#  "TAMERICAN ADVISORS GROUP'   T2ZY20IS",
#  "TAMBRICAN ADVISORS GROUP   YZAOIS WAFI/EONST FSA] TA RNDORSED '] AOGA] AGI FEH ETA AS0",
#  'AMERICAN ADVISORS GROUP\' __—   A/AZIAORS  27S/2OIA    GF     ENDORSED "  2.668] 5.25] 5 TEH YH AS A250',
#  'TAMERICAN ADVISORS GRUP',
#  "AMERICAN ADVISORS GROUP'   FANS",
#  "AMERICAN ADVISORS GROUP'   FOIS",
#  "TAMERICAN ADVISORS GROUP' __ NIS /20I3  A",
#  "AMERICAN ADVISORS GROUP'   ASF /2013",
#  'AMERICAN ADVISORS GROUP\'   AEONS] AVEA/ZOIA     ENDORSED "  2. 794[ 5.295] 25 NY WHIMS 20000 TZAGZO[42',
#  "AMERICAN ADVISORS GROUP'   TI201S",
#  "AMERICAN ADVISORS GROUP'   AA/APZYAOIS",
#  "TAMERICAN ADVISORS GROUP'   IPZYO0IS  S/AGVEOUA]  I]   ENDORSED '   29",
#  "TAMERICAN ADVISORS GROUP'   TAZYZOIS",
#  "AMERICAN ADVISORS GROUP'   AZ FA0IS   3YAVZOA     RNDORSED *] AOIS  8565 FTNT HAW A65000] 06755 33",
#  "AMERICAN ADVISORS GROUP' _—   TAISYOOIS",
#  "AMERICAN ADVISORS GROUP'   AANG] /A",
#  "AMERICAN ADVISORS GROUP'   A/2Z/O0IS",
#  "AMERICAN ADVISORS GROUP'   1A /2ZA0IG",
#  "TAMERICAN ADVISORS GROUP'   TTS20IS",
#  "AMERICAN ADVISORS GRUP' __   T",
#  "AMERICAN ADVISORS GROUP' __   AZ/ZIYAOIS  A/I",
#  "AMERICAN ADVISORS GROUP'   AZ/I/E0IS",
#  "AMERICAN ADVISORS GROUP'   ATZ/AMNA",
#  "TAMERICAN ADVISORS GROUP' 15203",
#  "AMERICAN ADVISORS GROUP'   A/E7AZOUA  A/VO/AOIA    WA]   ENDORSED *   GOR] 605] 25 TY YH A'   Z00",
#  'AMERICAN ADVISORS GROUP\'   A/ZYA0NA AVAYZOIA    TAF   BNDORSED "  2.907] 55A] 5 TEH YH AS 50',
#  "AMERICAN ADVISORS GROUP'   AA/ZAYAOIS",
#  'TAMBRICAN ADVISORS GROUP   AYZ0YA0IS AAYEONAT  ]    ENDORSED   E664] 5.8] EAT 580',
#  "AMERICAN ADVISORS GROUP'   AYZMNA",
#  "TAMERICAN ADVISORS GROUP 22RD] A/IO/EOIA  3VIZ/AORS  TO]     TORMINATED'   3.16) 583) NT AE 800",
#  "AMERICAN ADVISORS GROUP'   8 FOOIA",
#  "AMERICAN ADVISORS GROUP' __   2204",
#  "TAMERICAN ADVISORS GROUP'   A/20IA",
#  "AMERICAN ADVISORS GROUP'   TV",
#  'AMERICAN ADVISORS GROUP\'   AT AZOUA  S/A/ZOIA    GF   ENDORSED "  2. 78IF 5.5   625  \'NY WH A\'   00',
#  "AMERICAN ADVISORS GROUP'   A/ZOONAL",
#  "AMERICAN ADVISORS GROUP'   /20V2013",
#  "AMERICAN ADVISORS GROUP'   TOVZ0IA  5",
#  "AMERICAN ADVISORS GROUP'   /AMNA",
#  "AMERICAN ADVISORS GROUP'   AZVTTYO0IS",
#  "TAMERICAN ADVISORS GROUP'   TA20IS",
#  'AMERICAN ADVISORS GROUP\' __   AZ/2R7AOIS  A/IG/2OIA    GZ}   ENDORSED "  AIA] 6.05] 3.25 \'NY YH UA\'   60',
#  "AMERICAN ADVISORS GROUP'   A/ZFAONAL",
#  'TAMERICAN ADVISORS GROUP\'   ZOZ0NA  AFII/EOUAF   3] OF "ENDORSED §   OUN] 5.56] RS TNT TA   TISO',
#  'TAMERICAN ADVISORS GROUP A',
#  "TAMERICAN ADVISORS GROUP'   ZTAOIA  5",
#  "AMERICAN ADVISORS GROUP'  I 20UA  /IS/2O14",
#  "AMERICAN ADVISORS GROUP'   AAZ/AONA",
#  'AMERICAN ADVISORS GROUP\'   ZARA] AZO]       BNDORSED "  SZ] FATEH TYTN IS 990',
#  "AMERICAN ADVISORS GROUP'   A/AZOONAL",
#  "TAMERICAN ADVISORS GROUP'   A/AZ0ID",
#  "AMERICAN ADVISORS GROUP'   A/ZYA0NA",
#  "AMERICAN ADVISORS GROUP'   ATI FA0IAL",
#  "AMERICAN ADVISORS GROUP'   ZZYZOIA  AVA/EOUA]   SS]    ENDORSED '   5.06) 5.06] OTT 50",
#  'TAMERICAN ADVISORS GROUP\'   AZAAOIA  AVEO/EOUAF  E] 0]   "ENDORSED {3 A5AF SON TT AE 70',
#  "AMERICAN ADVISORS GROUP'   ATAZOIA  A/IS/ZOUA]   ES]   ENDORSED 1] 5.06) 5.06] OTT TH S50",
#  "AMERICAN ADVISORS GROUP'   A/Z/O0IA",
#  "AMERICAN ADVISORS GROUP'   ATONAL",
#  "AMERICAN ADVISORS GROUP'  E YOONA",
#  "TAMERICAN ADVISORS GROUP'   S2ZYZ0IA  YAVANNA]   OO]    TNDORSED   399 AF A TNT A 50",
#  "AMERICAN ADVISORS GROUP'   A/ZFOMIAL",
#  "AMERICAN ADVISORS GROUP'   5 /2ZA0UA  7VA/ZOIA    GF}   ENDORSED “  UG] SOS] ATH YT I'   3 000",
#  "AMERICAN ADVISORS GROUP'   A/DFOONA",
#  "TAMERICAN ADVISORS GROUP'   AZZ0IA  E/A/AOUA   ]   BNDORSED ].A52; PT AE T030",
#  "AMERICAN ADVISORS GROUP'   AFT /A0IA",
#  "AMERICAN ADVISORS GROUP' _   ATONAL",
#  "AMERICAN ADVISORS GROUP'   TGYZ0IA",
#  "AMERICAN ADVISORS GROUP'   5 /2DYAONA  ZANNA]     G2    ENDORSED *   2.SO9] A] TTY YH AS   G00",
#  "AMERICAN ADVISORS GROUP'   ATZ/AONA",
#  "AMERICAN ADVISORS GROUP'   ATG20NA",
#  'TAMERICAN ADVISORS GROUP\'   AVTTZOIA  SAN/EOUA  S/IR/EORS  7]     "TERMINATED\'   2.903) 5A] VTY TA ZI00',
#  "AMERICAN ADVISORS GROUP'   AFORE",
#  "AMERICAN ADVISORS GROUP' AAA",
#  "AMERICAN ADVISORS GROUP'   5",
#  "AMERICAN ADVISORS GROUP'   A/ZYAZOUA  6VE/ZOIA    WF   ENDORSED *   52] 7] ATH YH AS AT00",
#  "AMERICAN ADVISORS GROUP'   ATIONAL",
#  "AMERICAN ADVISORS GROUP' 5",
#  "TAMERICAN ADVISORS GROUP' TI /20IA  S/II/EOUA  AVAS/EORI  63]     TERMINATED'   2.904) 5A] AZ TN§ TH AE ST50",
#  "TAMERICAN ADVISORS GROUP' 87",
#  "AMERICAN ADVISORS GROUP'   AT 20N4",
#  "AMERICAN ADVISORS GROUP'   A/ZOOIA",
#  "AMERICAN ADVISORS GROUP' 5 AFAONA",
#  'TAMBRICAN ADVISORS GROUP   7NAYAOIA  SAS/AORAT   2]    ENDORSED "  5.06) 5.06F FT I900',
#  "TAMERICAN ADVISORS GROUP' 85",
#  "AMERICAN ADVISORS GROUP'   A FA0NA",
#  'AMERICAN ADVISORS GROUP\'   R/A0NA  PAT/ZOIA        BNDORSED "  2.403] 95   A5 TEH YH AE 3 150',
#  "AMERICAN ADVISORS GROUP'   A/TDAONAL",
#  "AMERICAN ADVISORS GROUP'   7A 2014",
#  'TAMERICAN ADVISORS GROUP\'   TTAZOIA  SEA/EOUAF  ]     "ENDORSED @   2.903) 5.37] ARTNET Z90',
#  "AMERICAN ADVISORS GROUP'   A/ 2014",
#  'AMERICAN ADVISORS GROUP\'   AAZYAZOUA  IGVA/ZOIA    TS]   ENDORSED "  2.907] A] 75TH YH UA\' 25000) TZZ',
#  "TAMERICAN ADVISORS GROUP'   NZTAZOIA] A/IA/AOIS   ]   TINDORSED {2.908 STA] EZ FUT TAE IS0",
#  "TAMERICAN ADVISORS GROUP'   8122014",
#  'AMERICAN ADVISORS GROUP\' __   88204] OVIE/ZOIA    TF   ENDORSED "  2.656] A] STH YH A\' I500} E705',
#  "AMERICAN ADVISORS GROUP'  I /2014",
#  "AMERICAN ADVISORS GROUP' __   GTS",
#  'TAMERICAN ADVISORS GROUT 87',
#  "TAMERICAN ADVISORS GROUP'   220I] A/ER/EOIS    8]    ENDORSED   2 9ZNF 66] VST TAE 3320",
#  "AMERICAN ADVISORS GROUP'   Z/I/ZOIA",
#  'AMERICAN ADVISORS GROUP\' T/A /AONAL VI/IS/EOIA    OFT]   ENDORSED "  2.653] 06] FTNY WU IW 625500] S6A666',
#  'AMERICAN ADVISORS GROUP\'   TO2Z0N4  NIA/ZOIA        RNDORSED "  2.904] AIF] 5 TEH YH NI\' 30',
#  "AMERICAN ADVISORS GROUP'   FAA",
#  'AMERICAN ADVISORS GROUPT',
#  'AMERICAN ADVISORS GROUP\' _   TO/ZYAOUA  TI/AO/ZOA    TF    ENDORSED "  2.907] 5.06] TS TY WH AS   5000) 74',
#  "AMERICAN ADVISORS GROUP' _—   N/2G20I4",
#  "AMERICAN ADVISORS GROUP' ATOMS",
#  "AMERICAN ADVISORS GROUP'   ASF /2014",
#  'TAMERICAN ADVISORS GROUP"   N0',
#  "AMERICAN ADVISORS GROUP'   TO /2014",
#  "AMERICAN ADVISORS GROUP'   TO",
#  "TAMERICAN ADVISORS GROUP' T/T 2014",
#  "TAMERICAN ADVISORS GROUP'   AAZOIA  AI/EE/EOUAF   TO]   BNDORSED   2.902) 52ST TAE 380",
#  'TAMERICAN ADVISORS GROUP   A',
#  "TAMERICAN ADVISORS GROUP'   T0",
#  "AMERICAN ADVISORS GROUP'   A/TOAOIS",
#  "AMERICAN ADVISORS GROUP' T/A FOONA",
#  "TAMERICAN ADVISORS GROUP'   ATAZYZORA  AZ/A/EOUA  WS]   TINDORSED   2.906) 52A RT 30",
#  "AMERICAN ADVISORS GROUP'   FAA I",
#  "AMERICAN ADVISORS GROUP'   /ZO0I5",
#  "AMERICAN ADVISORS GROUP'   TOI /20RA",
#  "TAMERICAN ADVISORS GROUP'   N0US/20I4  VI/IG/AOUAF   TS]   ENDORSED   2.403) AIF ZS TNT AE SAGO",
#  "AMERICAN ADVISORS GROUP' 842015",
#  "AMERICAN ADVISORS GROUP'   AZ/I",
#  "AMERICAN ADVISORS GROUP'   AYOZOUA  VIAGRA]         ENDORSED ‘  5.06] 5.06] AF' HT PTO",
#  "AMERICAN ADVISORS GROUP' A //A014",
#  "AMERICAN ADVISORS GROUP'   2014",
#  'AMERICAN ADVISORS GROUP\'   ATORS YG/ZOIA    OF   BNDORSED "  2.532] 985] 75 FTNH YH AS AT Z0',
#  "AMERICAN ADVISORS GROUP'   A/Z/A0IS",
#  'TAMERICAN ADVISORS GROUP\'   ZAYOOIA  AAR/AOIS    AR]     ENDORSED "  2.654) SOF TNT AE 3T50',
#  "TAMERICAN ADVISORS GROUP'   A//20I5",
#  'AMERICAN ADVISORS GROUP\'   TZY3IZOID  I/AG/AOIS   ]   A  "ENDORSED 1] GIO) 5] RT TT ATZ0',
#  "AMERICAN ADVISORS GROUP' ZFS FOOIALI",
#  "AMERICAN ADVISORS GROUP'   A/TG2015",
#  "AMERICAN ADVISORS GROUP'   AZYAMNA",
#  "AMERICAN ADVISORS GROUP'   AZFEAMNA",
#  "AMERICAN ADVISORS GROUP'   A/A6A0IA",
#  'TAMERICAN ADVISORS GROUP\'   TZ2Z/A0IA AVEN/AOIS    8]    "ENDORSED VT EOF 5.2] RST TA 150',
#  'TAMERICAN ADVISORS GROUPT AZ /A01A',
#  "AMERICAN ADVISORS GROUP'   AVE7Z0IS  S/AD/AOIS    WA]    ENDORSED '   2.922{ A. G6F SFT TT   T530",
#  "AMERICAN ADVISORS GROUP' _   A/TOV2OI5  4VA/2OIS          ENDORSED *   2.925]   TY YT NAS   T50",
#  "AMERICAN ADVISORS GROUP'   2A FAMIS",
#  "TAMERICAN ADVISORS GROUP'   3I20IA",
#  "TAMERICAN ADVISORS GROUP'   Z3IZ0IA",
#  "TAMERICAN ADVISORS GROUP'   ATZZOIS  2VS/AONS   ] ASSIGNED   32",
#  'TAMERICAN ADVISORS GROUP   T/20I5',
#  "AMERICAN ADVISORS GROUP'  G /2015",
#  'AMERICAN ADVISORS GROUP™   AZ/G/AOIAL',
#  'AMERICAN ADVISORS GROUP AA /A0IS',
#  "AMERICAN ADVISORS GROUP' _   /ZYA0I5",
#  "AMERICAN ADVISORS GROUP'   AV27Z0IS  S/AI/EOIS    WS]    ENDORSED '   29",
#  'AMERICAN ADVISORS GROUP\'   ATOMS   AVO/AOIS        ENDORSED "  2.GU7] A 86] 75 NH YH UA\' 205000) TUZ5',
#  'AMERICAN ADVISORS GROUP\'   8T20I5   4VE/ZOIS      TA]   BNDORSED "  2.925]   TH YH IS 3660',
#  "TAMERICAN ADVISORS GROUP'   T62015",
#  'AMERICAN ADVISORS GROUP\' _   205] I/ASVAOIS         ENDORSED "  2S} 5.03] A 75 YH A\'   N65',
#  "AMERICAN ADVISORS GROUP' _   AT 20IS",
#  "AMERICAN ADVISORS GROUP'   AOAMI5",
#  "TAMERICAN ADVISORS GROUP' 22018",
#  "AMERICAN ADVISORS GROUP'   TGYZ0IS",
#  "AMERICAN ADVISORS GROUP' _—   A/TZ/20IS",
#  "AMERICAN ADVISORS GROUP'   332015",
#  "AMERICAN ADVISORS GROUP'   A/AA0IS",
#  "AMERICAN ADVISORS GROUP'   ATTYA0I5",
#  "TAMERICAN ADVISORS GROUP' 22015] 2VAS/EOIS    TO]    ENDORSED *   5.06) 5.06] OFT 20",
#  "AMERICAN ADVISORS GROUP'   AAA",
#  'TAMERICAN ADVISORS GROUPT   27',
#  "TAMERICAN ADVISORS GROUP'   ZVA0I5  A/IZ/EOIS    A]   ENDORSED @] A.923F A 86ST AE T100",
#  "TAMERICAN ADVISORS GROUP'   ATZYA0IS  A/IN/EOIS   E]    BNDORSED 1 {29",
#  "AMERICAN ADVISORS GROUP'   AVTGYZ0I5",
#  "AMERICAN ADVISORS GROUP'   A/2Z/A0IS",
#  "AMERICAN ADVISORS GROUP'   3205",
#  "AMERICAN ADVISORS GROUP'   A/Z7AMI5",
#  "TAMERICAN ADVISORS GROUP'   AVT9VZ0I5",
#  "AMERICAN ADVISORS GOUP' __   /2YA0I5",
#  "AMERICAN ADVISORS GROUP'   A//20I5",
#  "AMERICAN ADVISORS GROUP'   AZZMIS",
#  'AMERTCAN ADVISORS GROUP',
#  "TAMBRICAN ADVISORS GROUP'   87",
#  "TAMERICAN ADVISORS GROUP'   A/620I5",
#  "AMERICAN ADVISORS GROUP' __   AF20U5",
#  "TAMERICAN ADVISORS GROUP'   AZ0V20I5  E/A/AOIS   E]   TINDORSED   A.932F AS] ZZ FN AE A6T0",
#  'AMERICAN ADVISORS GROUT   AFT /2015',
#  "AMERICAN ADVISORS GROUP'   ATYA0I5",
#  "TAMERICAN ADVISORS GROUP'   T",
#  'AMERICAN ADVISORS GROUP\'   ATZO0US   AVA/AOIS      GZ]   ENDORSED "  2.925]   TTY YH A\'   2520',
#  "AMERICAN ADVISORS GROUP'   87",
#  "TAMERICAN ADVISORS GROUP'   A/20I5",
#  "TAMERICAN ADVISORS GROUP'   U/20I5  Z/EO/AOIS    8]    BNDORSED @] 5.06) 5.06 ] OFT 35",
#  'TAMERICAN ADVISORS GROUP 47',
#  "AMERICAN ADVISORS GROUP'   3201S",
#  "AMERICAN ADVISORS GROUP' _—   A/ZDYA0IS",
#  "AMERICAN ADVISORS GROUP'   A5 2015",
#  "TAMERICAN ADVISORS GROUP'   A/2A0IS",
#  'TAMERICAN ADVISORS GROUP   A7 72018',
#  "AMERICAN ADVISORS GROUP'   AF YOOIS",
#  "AMERICAN ADVISORS GROUP'   AA FOIS",
#  "TAMERICAN ADVISORS GROUP'   AA /E0US",
#  "AMERICAN ADVISORS GROUP'   AARON",
#  'AMERICAN ADVISORS GROUP\'   TO/29Y2015  TI/AO/ZOIS        ENDORSED "  2.G4A] A6] 75H YH AT   520',
#  "AMERICAN ADVISORS GROUP'   8TZY20I5",
#  "AMERICAN ADVISORS GRUP'   AY",
#  "AMERICAN ADVISORS GROUP'   A/ZO0IS",
#  "AMERICAN ADVISORS GROUP'   6420S",
#  'TAMERICAN ADVISORS GROUP\'   ATAZ0IS  S/EO/AOIS   ]    "ENDORSED 1] 29',
#  "AMERICAN ADVISORS GROUP'   TO/26 2015] TI/IG/2OIS    TAF GI]   ENDORSED ‘  3.576] 73] 75 'NY TAH UT YT 519000) 3025",
#  "AMERICAN ADVISORS GROUP'   A/ZZ/AMIS",
#  "TAMERICAN ADVISORS GROUP'   AZGY20I5",
#  "TAMERICAN ADVISORS GROUP'   AY3020I5",
#  "AMERICAN ADVISORS GROUP'   A7 /2015",
#  "AMERICAN ADVISORS GROUP'   AZ YO0IS",
#  "AMERICAN ADVISORS GROUP'   5420S",
#  "AMERICAN ADVISORS GROUP' A /2",
#  "TAMERICAN ADVISORS GROUP' ___   7IS/20I5",
#  'TAMERICAN ADVISORS GROUP\'   R/IZOIS  G/S/AOIS    8]     "ENDORSED   2.997) A7] VST TAE   2000',
#  "AMERICAN ADVISORS GROUP'   A/ZAMIS",
#  "TAMERICAN ADVISORS GROUP'   TGVZ0IS",
#  "AMERICAN ADVISORS GROUP' 6 A/20I5",
#  "AMERICAN ADVISORS GROUP'   R/O",
#  "AMERICAN ADVISORS GROUP'   6T920I5",
#  "TAMERICAN ADVISORS GROUP'   A/820IS  S/IZ/AOIS   ]    TINDORSED   938)   ZT AE 850",
#  'AMERICAN ADVISORS GRUP\'   220I] TO/IE/2OIS    3]     "ENDORSED 1] 2.957) 50A] VS TNT TT 50',
#  "AMERICAN ADVISORS GROUP' __   A/TOYA0I5",
#  "AMERICAN ADVISORS GROUP'   A/E",
#  "AMERICAN ADVISORS GROUP' _—   GTYOOIS  9VIS/2OIS    GI   80]   ENDORSED *   2.OUIF 5.05] 75 'NY YH A' 35000) SG6",
#  "AMERICAN ADVISORS GROUP'   9A 2015",
#  "TAMERICAN ADVISORS GROUP' __   87",
#  "TAMERICAN ADVISORS GROUP' 812015",
#  "AMERICAN ADVISORS GROUP'   TO /2015",
#  "AMERICAN ADVISORS GROUP'   /2",
#  "TAMERICAN ADVISORS GROUP'   07",
#  "TAMERICAN ADVISORS GROUP'   N",
#  'TAMERICAN ADVISORS GROUP   AI7A 2015',
#  "AMERICAN ADVISORS GROUP' _—   T",
#  "AMERICAN ADVISORS GROUP' __—   TAASYOOUS  I",
#  "AMERICAN ADVISORS GROUP'   N",
#  "TAMERICAN ADVISORS GRUP'   T0V",
#  'AMERICAN ADVISORS GROUP\'   N/A   P/E/AOIS   G]   ENDORSED "  2.942 A7 TS FTNH TWIT AS00',
#  "AMERICAN ADVISORS GROUP' __—   ATY20I6",
#  "AMERICAN ADVISORS GRUP'   T0",
#  "AMERICAN ADVISORS GROUP'   TOF FO0IS   1I7E/20IS",
#  "TAMERICAN ADVISORS GROUP'   ITOZ0IS",
#  'AMERICAN ADVISORS GROUT   FAIS',
#  "TAMERICAN ADVISORS GROUP' 22016",
#  "AMERICAN ADVISORS GROUP'   2 FO0N6",
#  "AMERICAN ADVISORS GROUP' _   TZISYAOIS",
#  'AMERICAN ADVISORS GROUP\' _   AZ/IGYAOI5  I/AI/ZO6    TAF 80] 2 ENDORSED "  GSI] AS} 75 NH YH IS 3T0',
#  "AMERICAN ADVISORS GROUP'   AZN] AY",
#  'TAMERICAN ADVISORS GROUP 27',
#  'AMERICAN ADVISORS GROUP\'   /2YA0I5  I/AI/ZOIE        ENDORSED "  A.S6A]   75  \'Y TA) UTY\'   600',
#  'TAMERICAN ADVISORS GROUPT   17',
#  "AMERICAN ADVISORS GROUP'   AZ/IZYA0IS",
#  "AMERICAN ADVISORS GROUP'   T/Z0I6  2VA/AOIS    3]   ENDORSED   3.928) 95] RS FTNTÉ TAT AV   75000  T0AS25  35",
#  "AMERICAN ADVISORS GROUP'   AFT/OOIE",
#  "AMERICAN ADVISORS GROUP' __   A0I6",
#  "AMERICAN ADVISORS GROUP'   AF /A0I6",
#  "AMERICAN ADVISORS GROUP'   A2",
#  'TAMERICAN ADVISORS GROUT /T',
#  'AMERICAN ADVISORS GROUT   ATONE',
#  "AMERICAN ADVISORS GROUP' _   AIGY20I6",
#  "TAMERICAN ADVISORS GROUP'   AZ FO0N6",
#  "AMERICAN ADVISORS GROUP'   2A Z0N6   2",
#  "TAMERICAN ADVISORS GROUP'   A/ZZ0IE  SAVZOUS   E]   INDORSED §   3.80) AGER TNT TAT TAY Z500",
#  "AMERICAN ADVISORS GROUP'   WT /20I6",
#  "AMERICAN ADVISORS GROUP'   AZZ /A0I6",
#  "AMERICAN ADVISORS GROUP'   8 N",
#  "AMERICAN ADVISORS GROUP' _   AT",
#  "AMERICAN ADVISORS GROUP'   AAYOMNG",
#  "AMERICAN ADVISORS GROUP'   AA FOMNG  5",
#  'TAMERICAN ADVISORS GROUP   ATAYZ0I6  SFE/AOIS    TS]   ENDORSED   3.955) A5] VST RAT TAY   3300',
#  "AMERICAN ADVISORS GROUP'   AAD YO0NG",
#  'TAMERICAN ADVISORS GROUT A7 /20I6',
#  "AMERICAN ADVISORS GROUP'   ATTZ0I6",
#  "AMERICAN ADVISORS GROUP'   STIAZ0U6  OVG/2OI6        ENDORSED *   4.225] A7] A TTY TAH UT Y'S SO",
#  'AMERICAN ADVISORS GROUP\'   A/AZ0I6  AVAG/EOIS    3]   2  "ENDORSED \'   5.06) 5.06] OTT TH 300',
#  "AMERICAN ADVISORS GROUP'   6A /O0N6",
#  "AMERICAN ADVISORS GROUP'   AA /A0N6   A",
#  "TAMERICAN ADVISORS GROUP'   AZZ FO0N6",
#  "AMERICAN ADVISORS GROUP'   A/2320I6",
#  "AMERICAN ADVISORS GROUP' __ S/T 2016",
#  "TAMERICAN ADVISORS GROUP' __   ZAYZOI6",
#  "AMERICAN ADVISORS GROUP'   A5 /2016",
#  "AMERICAN ADVISORS GROUP'   TD YO0N6",
#  "AMERICAN ADVISORS GROUP'   645 /A0N6",
#  "AMERICAN ADVISORS GROUP' 0 /O0I6",
#  "AMERICAN ADVISORS GROUP'   16207",
#  "TAMERICAN ADVISORS GROUP'   97",
#  'TAMERICAN ADVISORS GROUPT 67',
#  "AMERICAN ADVISORS GROUP' __—   622016",
#  "AMERICAN ADVISORS GROUP'  R FO0N6",
#  "TAMERICAN ADVISORS GROUP' TZ/A0I6",
#  'AMERICAN ADVISORS GROUP\' __—   GTZA0I6  OVE/2OI6        BNDORSED "  AA]   TEH TAT YT   990',
#  "TAMERICAN ADVISORS GROUP'   R",
#  "AMERICAN ADVISORS GROUP'   Z//O0N6",
#  'AMERICAN ADVISORS GROUP\'   /AYO0U6  AZIZ]         ENDORSED "  4.52] KOS] ATH TAT TY\' 325000] AS7Z',
#  "TAMERICAN ADVISORS GROUP' _   USY20I6  OVO/AOIE   E]    BNDORSED 1] A 526) A] TNT RAT AY 70",
#  "TAMERICAN ADVISORS GROUP'   T/20I6",
#  "AMERICAN ADVISORS GROUP'   9A 206",
#  'AMERICAN ADVISORS GROUP\'   AAOMNG   S/ZOR7          BNDORSED "  4.305] 93] 5 TEH TAT YT 625500] G003Z',
#  "AMERICAN ADVISORS GROUP'   G/TZ20I6  OVA/2OI6          ENDORSED *   4.725] OZ] 3.25 'YY TAH UT IY'   3000",
#  "AMERICAN ADVISORS GROUP'   97",
#  "AMERICAN ADVISORS GROUP'   TAYZ0I6  IZ/IG/EOIS    SA]   ENDORSED   45",
#  "TAMERICAN ADVISORS GROUP' _—   T0",
#  "TAMERICAN ADVISORS GROUP'   TZZOI7",
#  'AMERICAN ADVISORS GROUP\'   T/T 201611727206]     A RNDORSED "  5.77] 5.055] 625 [NT TAH TAY ASOO00 ANIG60F 32',
#  "TAMERICAN ADVISORS GROUP'   AVAZAZON7",
#  "TAMERICAN ADVISORS GROUP'   ZY2Z/Z016  A/ES/EOU7  UIIA/ZOIG  ES]     TERMINATED'   A.EO3) AZ] TT RAT TAY 50",
#  "AMERICAN ADVISORS GROUP'   TOISZYOOU6  AI",
#  'AMERICAN ADVISORS GROUP\'   AZZAMNG   VE/ZOR7 _   TF   BNDORSED "  46A] AF TRE TAY\'   3520',
#  "TAMERICAN ADVISORS GROUP' _   A/Y20I6  _A/S/EOUZ ]  }    BNDORSED 1] A 6A5) AF TT RAT TAY   AZ00",
#  "AMERICAN ADVISORS GROUP' AA /20N6",
#  "TAMERICAN ADVISORS GROUP'   ATG/Z0R7",
#  'AMERICAN ADVISORS GROUP\' AFT FOONZ   A/AR/ZO7       ENDORSED "  436] 5.025] EAS  *NY TAH IY AS00',
#  "AMERICAN ADVISORS GROUP'   A/ZYAOU7  A/IGZO7    TS   ENDORSED *   AAA} 53] EY TAH YT   GZ0",
#  'AMERICAN ADVISORS GROUP\'   ZTYONN7   AAN/AOR7 _—       BNDORSED "  5.06] 5.06] OTH TE A750',
#  'TAMERICAN ADVISORS GROUT 742016] 1I7E',
#  "AMERICAN ADVISORS GROUP'   TAUGY20I6  I/I",
#  'AMERICAN ADVISORS GROUP\'   A/Z020I7 A/NOVZOR7 _       BNDORSED "  AZZ] 4405] 75 EH TAH YT 50',
#  "AMERICAN ADVISORS GROUP'   A/ZZYA0I7  3A/ZOI7          ENDORSED *   4735] A} ATH TAT YT 205000) TOIZ",
#  'AMERICAN ADVISORS GROUP\'   592017] 6E20I7 _—       BNDORSED "  3.994] 58} TEH YH IE 50',
#  "AMERICAN ADVISORS GROUP'   5FT",
#  'AMERICAN ADVISORS GROUP\'   A/5FO0N7   /AE/AOI7     TA RNDORSED "  A 73A] PATH PA TIY T60000[ E720 32',
#  "AMERICAN ADVISORS GROUP'   AVZZOR7  G",
#  "AMERICAN ADVISORS GROUP' _   AZ/ZIYAOI6  I/AA/2OI7 _   TOF TA]   ENDORSED *   4.693}   ATH TAH YT   S60",
#  'AMERICAN ADVISORS GROUP\'   AZVGYA0I6  I/IG/ZO7 _     83]   BNDORSED "  A6AS] ASA] A TEH TAT YT   G50',
#  "AMERICAN ADVISORS GROUP'   A/AZ/A0I7",
#  "AMERICAN ADVISORS GROUP'   A/2020I7",
#  "TAMERICAN ADVISORS GROUP'   ATYZ0I7",
#  'TAMERICAN ADVISORS GROUP\'   Z0I7  A/AVEOUZ    TO]  "ENDORSED {4 A35] 5.05] ZS FTNT§ RAT TAY   3AS0',
#  "AMERICAN ADVISORS GROUP'   AZ FOOI7",
#  'AMERICAN ADVISORS GROUP\'   OZMN7  AVE/ZOI7 _—       BNDORSED "  5.061[ 5.055] 75 NY TAH YT G50',
#  "AMERICAN ADVISORS GROUP' __   A",
#  'AMERICAN ADVISORS GROUP\'   A/AYAMN7   AVAR/ZOR7 _   TIF TO]   ENDORSED "  AVA] A 93] AG FH AT NYT 50',
#  "AMERICAN ADVISORS GROUP'   2207",
#  'AMERICAN ADVISORS GROUP\'   A/Z/AON7   A/ASYAOI7        ENDORSED "  4.608] A 995  75 [NY TAH TIV 3 000',
#  'AMERICAN ADVISORS GROUP\'   ATAYA0N7   S/IO/ZOI7 _   TIF     ENDORSED "  4.453] 495] 5 TEH TAG YT   G250',
#  'AMERICAN ADVISORS GROUP\'   AIZAZOU7  A/IS/2OU7 _—       ENDORSED "  4703} A9} ATH TAT YT T00',
#  "TAMERICAN ADVISORS GROUP'   AVZYAOI7  S/ESVEOUZ   } ENDORSED 1] 3.5ANF 5.5] RST TAE 550",
#  "TAMERICAN ADVISORS GROUP'   YZZYA0I7 S/SO/AOUZ   ]   BNDORSED 1] 4235) AF TNT RAT TAY 36",
#  "AMERICAN ADVISORS GROUP' _   AIGYA0I7",
#  "AMERICAN ADVISORS GROUP' AA /AON7",
#  "AMERICAN ADVISORS GROUP'   AFT /O0N7",
#  "AMERICAN ADVISORS GROUP'   AZ /AMN7",
#  "AMERICAN ADVISORS GROUP'   A/IFOON7",
#  "AMERICAN ADVISORS GROUP' 6A /2017",
#  "AMERICAN ADVISORS GROUP'   A/TOVE0I7",
#  'AMERICAN ADVISORS GROUP\'   AAZYOONZ   S/E/ZOV7    WA A NDORSED "  ASAGF 06] TANH TA TIV AO00',
#  "AMERICAN ADVISORS GROUP'   AA OON7",
#  "AMERICAN ADVISORS GROUP'   9A AZ0N7",
#  'TAMERICAN ADVISORS GROUP   ATZ/A0I7',
#  "AMERICAN ADVISORS GROUP'   A/ZIFOON7",
#  'AMERICAN ADVISORS GROUT   AF FOONZ   S/IG/AOI7    TOF    ENDORSED "  A4SZ{ 506] ES F*NT PA IY 3300',
#  "AMERICAN ADVISORS GROUP' 5 /2Z/O0I7",
#  "AMERICAN ADVISORS GROUP' _—   W820I7  ZAR/GOR7 _   7]   ENDORSED *   AASI  9] TTY TAH UY'   ZOO",
#  "AMERICAN ADVISORS GROUP'   5A 2017",
#  "AMERICAN ADVISORS GROUP'   A/TZO0I7",
#  'AMERICAN ADVISORS GROUP\'   2YZOR7  E/AN/EOIZ ]   8]     "ENDORSED \'   GAA] 5.03 GT TAT TTY   97',
#  'TAMERICAN ADVISORS GROUP\'   ZYZOR7  E/ISVEOUZ ]  ]     "ENDORSED 1] A TEA] AOA AFIN RAT AY   550',
#  "AMERICAN ADVISORS GROUP'   662017] W/A0VAOI7 ]   EA]   ENDORSED 1] DAZ] 5.01] GOT RAT AY 35",
#  'AMERICAN ADVISORS GROUT   TSFOON7',
#  'TAMERICAN ADVISORS GROUPT 87',
#  'AMERICAN ADVISORS GROUT   A/D/O0N7',
#  "AMERICAN ADVISORS GROUP'   R",
#  "TAMERICAN ADVISORS GROUP'   ATZOIS",
#  "AMERICAN ADVISORS GROUP'  G /2Z20I7  ZIG]   OF   ENDORSED *   AEI2] SO] A GA F'YY TAH YT   AS4GO",
#  'AMERICAN ADVISORS GROUP\' __   TOA /20I7  TO/EA/ZOI7 _—       BNDORSED "  4.625] 5.06] A 5 NH TAT NT YT   2640',
#  "AMERICAN ADVISORS GROUP'   /ZFOON7",
#  'TAMERICAN ADVISORS GROUP   N',
#  'AMERICAN ADVISORS GROUP\'  I A0I7   OVER/ZOI7 _       RNDORSED "  4728] 53} TEH TAT YT G30',
#  "AMERICAN ADVISORS GROUP'   ATYO0N7   S/IO/ZOI7 _—       BNDORSED   A APF 505] 5 TEH TAH YT 50",
#  "AMERICAN ADVISORS GROUP'   R/Z",
#  'AMERICAN ADVISORS GROUT   A/ZZFOONT   O/UI/AOR7  PT NDORSED "  A6ASF OAT OA TNH PA IY S00',
#  "TAMERICAN ADVISORS GROUP'   T/Z0I7  OVSVAOUZ ]   A]    BNDORSED {A 643] 5.06] ZG TNT RAT AY   T6Z0",
#  'AMERICAN ADVISORS GROUP\'   8Z0I7 S/AI/ZOR7        BNDORSED "  4643] 5.06] GAH TAT AY 7000] E654',
#  "AMERICAN ADVISORS GROUP'   TO/TOYZ0R7   UIV",
#  'AMERICAN ADVISORS GROUP\'   AETIOOR7  A/II/ZOIS    TAT OG] ENDORSED "  A 7E1F 52] TEH TA YT P200',
#  "TAMERICAN ADVISORS GROUP'   O",
#  'TAMERICAN ADVISORS GROUP   N07',
#  "AMERICAN ADVISORS GROUP' _   /OYA0I7",
#  'AMERICAN ADVISORS GROUP\'   TOTGYAOI7  VIFIS/ZOU7    TF   BNDORSED "  4.563] 5.05] 5 RY TA AY 2T00',
#  'AMERICAN ADVISORS GROUP\'   ZON7 T27S/ZOI7 _—   A A]   "ENDORSED "  4.678] 5.06] A AYY TAH NYT   2T00',
#  'AMERICAN ADVISORS GROUPY   AZ/AIOOI7   AVAS/ZOIS     ENDORSED "  45{ 06] EOF TNH TA IY 3 000',
#  'AMERICAN ADVISORS GROUP\'   TO/YOON7  IIAE/AOI7     A NDORSED "  4661 06] AF TNH TA IY 00',
#  "AMERICAN ADVISORS GROUP' __   OZON7",
#  "AMERICAN ADVISORS GROUP' AN /Z/A0N7",
#  "AMERICAN ADVISORS GROUP'   FO0IS   /A",
#  'AMERICAN ADVISORS GROUP   AA/ONOON7   IZ/A',
#  'AMERICAN ADVISORS GROUP\'   AZ/ZYAOI7  I/ESVZOIS        BNDORSED "  A8] 5.06] SA FYH TA AY 70',
#  "TAMERICAN ADVISORS GROUP'   A/AAOIS A/EEVEOIS   E]    ENDORSED 1] AGE] 5.32] ETN TAT TAY   SZ0",
#  "AMERICAN ADVISORS GROUP' A2",
#  'AMERICAN ADVISORS GROUP\'   AZIAZYAOI7  AVE/ZOIS    TIF TO]   ENDORSED "  AGAI] 5.06] A GAYE TA NT IY\'   AS50',
#  'AMERICAN ADVISORS GROUP\'   ZON7  TIVER/ZOI7 _   SOF     ENDORSED "  A.SIS} 5.06] 97  E TAT NY\'   A580',
#  'AMERICAN ADVISORS GROUP\'   AZFEO0N7  IFIO/ZOIS    TOF   BNDORSED "  4 SOF 5.06] GA FTYH TA AY   SA5',
#  "AMERICAN ADVISORS GROUP' A/B /O0IS",
#  'TAMBRICAN ADVISORS GROUP   AZAYAOR7  AEFIAFEOR7   E] 8]   ENDORSED] AO46] 5.06] OA FTNÉ FRAT AYE   T600',
#  "TAMERICAN ADVISORS GROUP' __   ZZ",
#  'AMERICAN ADVISORS GROUP\'   AN/ZTYA0N7   IA/IA/ZOI7 _     TO]   BNDORSED "  4.836] 5.06] GH TAH YT   3050',
#  "TAMERICAN ADVISORS GROUP'   TT/20I7",
#  "AMERICAN ADVISORS GROUP' AAA /O0N7   AA",
#  "AMERICAN ADVISORS GROUP'   A/DFOONS",
#  "AMERICAN ADVISORS GROUP' A FAOIS",
#  "AMERICAN ADVISORS GROUP'   AVAAFOOIS",
#  'TAMERICAN ADVISORS GROUP\' _   AOVZNIS  S/A/AOIS    A]     "ENDORSED   DOOR] AA] ZT RAT TAY   G0',
#  "AMERICAN ADVISORS GROUP'   TGYZOI8",
#  "AMERICAN ADVISORS GROUP' A2 F20IS",
#  'AMERICAN ADVISORS GROUT   8A /OOIS',
#  "AMERICAN ADVISORS GROUP'   A/ZO0I8",
#  'TAMERICAN ADVISORS GROUP E/A AOR7 A',
#  'AMERICAN ADVISORS GROUT   A6 /O0IS',
#  'TAMERICAN ADVISORS GROUP   2I/AOI7 I/A',
#  "AMERICAN ADVISORS GROUP'   ATY20I8",
#  "AMERICAN ADVISORS GROUP'   2AM",
#  "TAMERICAN ADVISORS GROUP'   AVZ",
#  "AMERICAN ADVISORS GROUP'   TY20I8",
#  "AMERICAN ADVISORS GROUP'   A6 /O0IS",
#  "AMERICAN ADVISORS GROUP'   AAZFAOIS",
#  "AMERICAN ADVISORS GROUP' _—   AIGYZ0IS",
#  "AMERICAN ADVISORS GROUP' __   ATOYZNIS",
#  "AMERICAN ADVISORS GROUP' __—   A/YO0IS",
#  "TAMERICAN ADVISORS GROUP'   AV",
#  "AMERICAN ADVISORS GROUP'   ATY20IS   5Y",
#  "AMERICAN ADVISORS GROUP' 5A AOS",
#  "AMERICAN ADVISORS GROUP'   A6 /2018   A/A",
#  'AMERICAN ADVISORS GROUPY 5 FTAOOIS',
#  "AMERICAN ADVISORS GROUP'   AZ0Y20I8  S/US/EOIS    EA]    ENDORSED 1] A 7EIF APE] OFT TAT TAY 75",
#  'AMERICAN ADVISORS GROUT 5 AZ/OMIS',
#  "AMERICAN ADVISORS GROUP' _  G",
#  "AMERICAN ADVISORS GROUP' 5 TDAOIS",
#  "TAMERICAN ADVISORS GROUP   AI20I8  SYO/EOIS}   2]     ENDORSED '   A 951F 5.06] ZEN TAT TAY   3690",
#  "AMERICAN ADVISORS GROUP' 6A /20IS",
#  'AMERICAN ADVISORS GROUP\' __   AISYOQUS  O/S}   TAF   ENDORSED "  5.2A1F 5.39 SY TAH YT   SI7OO/ _SAZOS.S/ 36',
#  "AMERICAN ADVISORS GROUP' 5 /ZA0IS",
#  'TAMERICAN ADVISORS GROUP\'   TAZ0IS  TOVA/EOIS   ]    "ENDORSED 1] 3.526) 3.65] ES TNE TAT TAY   Z38',
#  "TAMERICAN ADVISORS GROUP'   8162018] G",
#  "AMERICAN ADVISORS GROUP' 5A FAOIS",
#  "AMERICAN ADVISORS GROUP'   6T620I8",
#  'TAMERICAN ADVISORS GROUP™ 725 /A0I9',
#  "AMERICAN ADVISORS GROUP'   9TT/20I8",
#  "AMERICAN ADVISORS GROUP'   GTI Z0IS   TO",
#  "AMERICAN ADVISORS GROUP'   A/ZFAOIS",
#  "AMERICAN ADVISORS GROUP' TOTAIS] TI/IS/ZOIS    SF   BNDORSED * FA 29F AFAR TEH TAT YT GGO",
#  'AMERICAN ADVISORS GROUP\'   820S] G/AS/2OIG        ENDORSED "  GAZ] 93} OAT\' TAH YT   G050',
#  "AMERICAN ADVISORS GROUP'   ATZ/A0IS",
#  'AMERICAN ADVISORS GROUP\'   TOSO0IS   IIS/2OIG    TF   A ENDORSED "  AVIS] ANF] EGG NH TAT NYT 500',
#  'AMERICAN ADVISORS GROUP\'   5 /ZAOUS   @/IA/ZOIG    79] 80]   ENDORSED "  5.75] 5 A3] A F\'NY TA) UY\'   G050',
#  "AMERICAN ADVISORS GROUP' __   W/ZOOUS",
#  "TAMERICAN ADVISORS GROUP' E5ANI9",
#  'TAMERICAN ADVISORS GROUP   07',
#  'TAMBRICAN ADVISORS GROUP   T0',
#  "TAMERICAN ADVISORS GROUP' T/T /2018",
#  "AMERICAN ADVISORS GROUP'   T/A /A0IS",
#  "TAMERICAN ADVISORS GROUP'   T/O20IS",
#  "AMERICAN ADVISORS GROUP' _—   ATSY20I9",
#  "AMERICAN ADVISORS GROUP'   AAZMNG",
#  "AMERICAN ADVISORS GROUP'   A/ZOMN9",
#  "AMERICAN ADVISORS GROUP' AF FOOIS I/AN/20I9",
#  'AMERICAN ADVISORS GROUP\' __   AZVIGYAOIS I/AO/ZOI9    TIF IF 2 BNDORSED "  4.73] 4. 795  75  WY TAT IY\'   600',
#  "TAMERICAN ADVISORS GROUP'   AZN] T",
#  "AMERICAN ADVISORS GOUP' _—   G/8Y20IS  TO/AI/ZOIS    GO]     ENDORSED *   5.5D9] 5.56] GAY TA) UY'   50",
#  "AMERICAN ADVISORS GROUP'   ATAYAZ0RS",
#  "TAMERICAN ADVISORS GROUP'   TTI20IS  VI/I/EOIS}   A] 8]   ENDORSED 1] ATOR ASA] SAT RAT TAY A390",
#  'TAMERICAN ADVISORS GROUP   17',
#  'AMERICAN ADVISORS GROUP\'   OYZMNG  AE/ZOI9    GF   BNDORSED "  5.215] AF] A5 FEE TAN IY\'   G6O',
#  "TAMERICAN ADVISORS GROUP'   Z/EY20IS  I/ESVEONO   E]    ENDORSED 1] 5.57] 5.5 AS TNT RAT TAY 50",
#  "AMERICAN ADVISORS GROUP' A",
#  "AMERICAN ADVISORS GROUP'   GAZ0IG",
#  "AMERICAN ADVISORS GROUP'   AZIZAZOIS  AIG]   WF OG] A BNDORSED *   A SAT] A] GH TAT NYT 50",
#  "AMERICAN ADVISORS GROUP'   AVE",
#  "AMERICAN ADVISORS GROUP'   AZ/2I/OOIS",
#  "AMERICAN ADVISORS GROUP'   TYAZNNG",
#  'AMERICAN ADVISORS GROUP\'   AANG] A/IAOIG  PF TA]   ENDORSED "  5.615] AIF] FTNY TA IY AT00',
#  "AMERICAN ADVISORS GROUP'   2A FA0N9",
#  'TAMBRICAN ADVISORS GROUP   T20I9  S/AO/ZNNPF   88] 80]   BNDORSED 8] A RAE] PTE RATE AYE   1300',
#  "TAMERICAN ADVISORS GROUP'   A/TYZNI9",
#  "TAMERICAN ADVISORS GROUP'   AYZYANI9  S/EOVAOIOF   TA]   ENDORSED V]5.TAA] OAT AS TNE RAT TAY   T860",
#  'TAMERICAN ADVISORS GROUPT   A/AAOIO',
#  "AMERICAN ADVISORS GROUP' __—   302019",
#  "AMERICAN ADVISORS GROUP' __—   A/26Y20I9",
#  "AMERICAN ADVISORS GROUP' 32019",
#  'AMERICAN ADVISORS GROUP\'   A/ZZYA0NG AVI/ZOIG          ENDORSED "  4.266] 06   EG FEE TAT YT 3 400',
#  "AMERICAN ADVISORS GROUP'   222019",
#  'AMERICAN ADVISORS GROUP\'   AZZONG   G/IA/ZOI9        BNDORSED "  5.426]   SAFTEY TAH YT   3850',
#  "AMERICAN ADVISORS GROUP' __—   A/20I9",
#  "AMERICAN ADVISORS GROUP'   ATTZOI9",
#  "AMERICAN ADVISORS GROUP'   ATG20I9",
#  'AMERICAN ADVISORS GROUP\' __—   5 /ZYAOIG /IZ/ZOI9      TA]   ENDORSED "  5.585] AT] 95  \'Y TAH UY\'   ATO',
#  'TAMBRICAN ADVISORS GROUP   27ANI9 Z/AN/AONPF  ] TA RNDORSED [AOA] ADO FEE RAT AYE 30',
#  'TAMERICAN ADVISORS GROUP 5 /8Z0I9  S/SO/AONN   E]    BNDORSED   5.676) A3] GST TAT TAY   T600',
#  "TAMERICAN ADVISORS GROUP'   87",
#  'TAMERICAN ADVISORS GROUP™ 67',
#  "AMERICAN ADVISORS GROUP'   WTZ/AZQNG",
#  "AMERICAN ADVISORS GROUP' 5 ASFAON9",
#  "AMERICAN ADVISORS GROUP'   AVIZAZONG",
#  "AMERICAN ADVISORS GROUP' 5A /2019",
#  "TAMERICAN ADVISORS GROUP'   SIZOI9",
#  'TAMERICAN ADVISORS GROUPT   /T',
#  "AMERICAN ADVISORS GROUP'   A/AGYAON9",
#  "AMERICAN ADVISORS GROUP'   AAZ0NG",
#  "AMERICAN ADVISORS GROUP'   ASYA0NG",
#  "AMERICAN ADVISORS GROUP'   AVASFAON9",
#  "AMERICAN ADVISORS GROUP'   AVAZFAONG",
#  'TAMERICAN ADVISORS GROUP"   99209} TOSIS/AOIP   E]     ENDORSED   DORA] A8 OAN RAT TAY A550',
#  "AMERICAN ADVISORS GROUP'   AVAGVZOR9",
#  "AMERICAN ADVISORS GROUP'   /T/ANN9",
#  "AMERICAN ADVISORS GROUP' __—   WIGVAOIG",
#  'AMERICAN ADVISORS GROUP\' _—   ZYZQNG Z/AIZOI9    SF   ENDORSED "  5.062] ASF 7  \'NY TAH UY\' 252000) IGAGI2] 4S',
#  'TAMERICAN ADVISORS GROUP   USZYANI9',
#  "AMERICAN ADVISORS GROUP' _—   G/TS/20I9  A/AD/ZOI9    GA}   ENDORSED *   57S} ASF] SOY TAH YT 65000) 9535] 33",
#  "AMERICAN ADVISORS GROUP'   OYZNI9  12",
#  'AMERICAN ADVISORS GROUP\'   ATZ0R9 OVIS/ZOI9          BNDORSED "  5.678] 51] 3. GONE TAH YT   600',
#  'TAMBRICAN ADVISORS GROUP   TS/20I9 Z//AONPF TA]    ENDORSED [4576] AAN] VANE FRAT TT AYE 80',
#  "AMERICAN ADVISORS GROUP'   6TZYA0N9",
#  "TAMERICAN ADVISORS GROUP'   TZ/ZOI9 Z/IE/AOIP   E] TA]   TINDORSED   826) A] AS TNT TAT TAY ISO",
#  "AMERICAN ADVISORS GROUP'   220I",
#  'AMERICAN ADVISORS GROUP™ TA YAON9',
#  "AMERICAN ADVISORS GROUP'   6AZA0N9",
#  "AMERICAN ADVISORS GROUP'   2TYZOIG",
#  "AMERICAN ADVISORS GROUP'   TONG",
#  "TAMERICAN ADVISORS GROUP'   7262019] OVA/AOIP    SO]    BNDORSED   A 8AS] AOS] GF TAT TAY 30",
#  'TAMERICAN ADVISORS GROUT 8 /T',
#  "AMERICAN ADVISORS GROUP'   TT/20I9",
#  "TAMERICAN ADVISORS GROUP'   G/ZOI9",
#  'TAMERICAN ADVISORS GROUP   O',
#  'AMERICAN ADVISORS GROUP\'   Z/OZOIG  A/Z/AOZOF   TA] TO]   "ENDORSED   5.262) 93 GIFT\' AT TAY   3500',
#  "TAMERICAN ADVISORS GROUP'   TAZOI9  TO/IZ/EOIG    GO]   ENDORSED 1] 5.690) 5.8] ATU TAT TAY 70",
#  'AMERICAN ADVISORS GROUP\'   TOTIZOR9  IIS/ZOI9        BNDORSED "  4.903] A6] 8.05 NY TA IY\' 352000] 323',
#  "TAMERICAN ADVISORS GROUP   92YZOI9  TO/AN/AOIP    8] 8]   ENDORSED '   4515] 3.93] A TNT RAT TAY 31 50",
#  "AMERICAN ADVISORS GROUP' __   A/AY2OI9  I",
#  'AMERICAN ADVISORS GROUP\' _—   TOZYA0R9] TI/IS/ZOI9    GF 80] 2 ENDORSED "  AO77] ASF] GA FTNH TA YT 3300',
#  'AMERICAN ADVISORS GROUP\'   AZ/ZIYAOIG  AVAI/2ON0    GO] GE]   ENDORSED "  546D] 5.8} A \'NY TA TY\' T270',
#  "AMERICAN ADVISORS GROUP'   TOIGYA0I9",
#  "AMERICAN ADVISORS GROUP'   AA/AAAOI9",
#  "AMERICAN ADVISORS GROUP' __—   A/TYA020",
#  "AMERICAN ADVISORS GROUP'   AZRASYAOR9",
#  "AMERICAN ADVISORS GROUP'   A8 F20",
#  "AMERICAN ADVISORS GROUP'   A//2020",
#  "AMERICAN ADVISORS GROUP'   AZ/ZZYAON9 A/I",
#  "AMERICAN ADVISORS GROUP'   AZ/IAZYAZOR9",
#  "TAMERICAN ADVISORS GROUP'   220I} IZ/AI/EOIP   ]     ENDORSED] S.2ANF AIF ASTER AY   T300",
#  "AMERICAN ADVISORS GROUP'   8A /O020",
#  "AMERICAN ADVISORS GROUP'   A/ZTYA020",
#  "AMERICAN ADVISORS GROUP'   A /2020",
#  "AMERICAN ADVISORS GROUP'   AZ/ZIAON9 /A",
#  "AMERICAN ADVISORS GROUP' _   AZ/IZAZOIG",
#  "AMERICAN ADVISORS GROUP'   AT /20",
#  "AMERICAN ADVISORS GROUP' _—   AZVIGYAOI9",
#  "TAMERICAN ADVISORS GROUP' __   AY",
#  "AMERICAN ADVISORS GROUP'   AZZOIG  I/AN/AOZOF  ]     ENDORSED 1] ASAD] AS] WAFT RAT TV   T050",
#  "AMERICAN ADVISORS GROUP'   A/TYAZ020",
#  "AMERICAN ADVISORS GROUP'   AA /2020",
#  "TAMERICAN ADVISORS GROUP'   TZ /2020} AAO/AONOF   TS]   ENDORSED] 5.A45] 5.8] WAFT RATTY 355",
#  "AMERICAN ADVISORS GROUP'   2A A020",
#  "AMERICAN ADVISORS GROUP'   G/D FO020",
#  "AMERICAN ADVISORS GROUP'   A7 /2020",
#  "AMERICAN ADVISORS GROUP'   A/T",
#  "TAMERICAN ADVISORS GROUP'   T07",
#  "AMERICAN ADVISORS GROUP'   5A 2020",
#  'TAMERICAN ADVISORS GROUP   T',
#  "AMERICAN ADVISORS GROUP'   T2Y2020  GV",
#  "AMERICAN ADVISORS GROUP'   5A /O020",
#  "AMERICAN ADVISORS GROUP'   Z/T",
#  'TAMERICAN ADVISORS GROUP™ 87',
#  "TAMERICAN ADVISORS GROUP' 77",
#  "AMERICAN ADVISORS GROUP' AA",
#  "AMERICAN ADVISORS GROUP'   AT /2020",
#  "TAMERICAN ADVISORS GROUP'   T2YZ020} AE/EOAN    82] 83]  TINDORSED 1] 837) AZ] FT TAT TAY A690",
#  "AMERICAN ADVISORS GROUP' __—   T",
#  'TAMERICAN ADVISORS GROUPT 10',
#  "AMERICAN ADVISORS GROUP' __—   /2020",
#  'AMERICAN ADVISORS GROUP™   N/N /2020',
#  "AMERICAN ADVISORS GROUP' __   T/T /2020",
#  "TAMERICAN ADVISORS GROUP'   A/5 2020] AA/EA/EOZOP  E]   TINDORSED {RAF 3.06] EA TNT RAT TAY AZ50",
#  "AMERICAN ADVISORS GROUP' AA /2IFA0N0",
#  "TAMERICAN ADVISORS GROUP'   /AYZO20}A/AVAOAN   ] INDORSED 1] 3.36) ZFS FEE AY 350",
#  "AMERICAN ADVISORS GROUP'   TO/2IFOO",
#  "AMERICAN ADVISORS GROUP'   TAZY2Z020",
#  "AMERICAN ADVISORS GROUP' AA /2D/O0N0",
#  'TAMBRICAN ADVISORS GROUP   T',
#  "TAMERICAN ADVISORS GROUP' AAA /2020  12",
#  "AMERICAN ADVISORS GROUP'   /2T/2020",
#  "AMERICAN ADVISORS GROUP' 1A /24A020",
#  "AMERICAN ADVISORS GROUP' A5 /20",
#  "TAMERICAN ADVISORS GROUP'   127",
#  'AMERICAN ADVISORS GROUT AF FOOZA   AA',
#  "AMERICAN ADVISORS GROUP' _   A/5A02I",
#  'AMERICAN ADVISORS GROUP\'   ATZYA0ZI 2VAE/ZOAI        ENDORSED "  279] A3] GAH YH YT 3 400',
#  "TAMERICAN ADVISORS GROUP' 25 /Z0AN  A/IV/AOAN    SO]    TINDORSED '{ ZEA] 3.6] SFT YT 26",
#  'AMERICAN ADVISORS GROUP\'   A/ZGYA0ZI 2VASVZOAI        BNDORSED "  SA] FAA YH YT YT 3 080',
#  "AMERICAN ADVISORS GROUP'   A/ZZAONI",
#  "AMERICAN ADVISORS GROUP'   9TZO0NI   1I7A/Z0R1  A",
#  'TAMERICAN ADVISORS GROUP™ 97',
#  'AMERICAN ADVISORS GROUP AZIZ',
#  "AMERICAN ADVISORS GROUP'   TOG",
#  "AMERICAN ADVISORS GROUP'   ATAYA0IZ",
#  "AMERICAN ADVISORS GROUP'   ATGYA0IS",
#  "AMERICAN ADVISORS GROUP'   AGY2Z0I3",
#  "AMERICAN ADVISORS GOUP' _—   A/20I3",
#  'TAMBRICAN ADVISORS GROUP   AVZYA0IS',
#  'TAMERICAN ADVISORS GROUP   /T',
#  "AMERICAN ADVISORS GROUP' _   ATI /20I3",
#  'AMERICAN ADVISORS GROUP\' 52013] 2E/2OI4          ENDORSED "  5.06] 5.06] ATH TE 5 200',
#  "AMERICAN ADVISORS GROUP'   O0IS",
#  "TAMERICAN ADVISORS GROUP'   /ZVZ0IS  SYS/EOUA    WE}   TNDORSED {A 9U6) 52] ER TNT TA 3800",
#  "AMERICAN ADVISORS GROUP'   TO/ZZYA0I3   IVE/ZOA       BNDORSED *] 272F   ATH YH IE 5 100",
#  "AMERICAN ADVISORS GROUP' 22RD] A/IS/20A",
#  "AMERICAN ADVISORS GROUP'   84204",
#  "AMERICAN ADVISORS GROUP'   /ZYAZ0NA] 5",
#  "AMERICAN ADVISORS GROUP'   AFT /2014",
#  "AMERICAN ADVISORS GROUP'   A/ZAZ0NA  5",
#  "AMERICAN ADVISORS GROUP'   AO AMNA",
#  "TAMERICAN ADVISORS GROUP'   58 /Z0NA",
#  "AMERICAN ADVISORS GROUP'   5 TZY20UA",
#  'AMERICAN ADVISORS GROUP\'   A/AONA   G/IS/EOIA        ENDORSED "  2.902{ SAT] RS FTNH TW IME A580',
#  "AMERICAN ADVISORS GROUP'   TO/TOY2ZO14",
#  "AMERICAN ADVISORS GROUP' AAA /A0IA",
#  "TAMERICAN ADVISORS GROUP'   N0T",
#  "TAMERICAN ADVISORS GROUP' 07",
#  'AMERICAN ADVISORS GROUP\'   AAS20NA ZG/ZOIA    TAF   BNDORSED "  2.907] AF TEH YH AE 3 700',
#  "AMERICAN ADVISORS GROUP'   AZ/Y20IA",
#  "AMERICAN ADVISORS GROUP'   TY2015",
#  "AMERICAN ADVISORS GROUP'   ATYA0IS",
#  "TAMERICAN ADVISORS GROUP'   AVTOVZ0I5",
#  "AMERICAN ADVISORS GROUP'   NFO",
#  "AMERICAN ADVISORS GROUP' _—   27IGY20I5",
#  "AMERICAN ADVISORS GROUP'   A /20I5",
#  "TAMERICAN ADVISORS GROUP'   AAA",
#  "TAMERICAN ADVISORS GROUP'   AZYZOIS",
#  'AMERICAN ADVISORS GROUT   8 /OOIS',
#  "TAMERICAN ADVISORS GROUP'   2201S",
#  "AMERICAN ADVISORS GROUP'   8TY20I5",
#  "AMERICAN ADVISORS GROUP' _   Z",
#  "TAMERICAN ADVISORS GROUP'   ZTIZOIS  AS/AOIS   ] OF  TNDORSED   5.06) 5.06] OFT TTS 50",
#  "AMERICAN ADVISORS GROUP' __   AZ/ZIYAOIS  A/IA/AOIE    OF   ENDORSED *] 5.06] 5.06] ANY RT 360000) ZOO] 56",
#  "AMERICAN ADVISORS GROUP'   /TAYA0I5  12",
#  "TAWERICAN ADVISORS GROUP'   ATIZ0I6",
#  'TAMERICAN ADVISORS GROUP AZAMIE',
#  "AMERICAN ADVISORS GROUP'   640 /20N6",
#  "AMERICAN ADVISORS GROUP'   A/ZFOOI6",
#  "AMERICAN ADVISORS GRUP' __   TT/Z0I6  AV",
#  "AMERICAN ADVISORS GROUP' __—   AOE",
#  'TAMERICAN ADVISORS GROUPT TZ /2016',
#  'AMERICAN ADVISORS GROUT   6A /2016',
#  "AMERICAN ADVISORS GROUP'   TANG",
#  "AMERICAN ADVISORS GROUP' __   8T",
#  'TAMERICAN ADVISORS GROUP 9232016] TO/IG/AOIS    RA]    TINDORSED 1] 45A] AS} ST RAT TAY TZ00',
#  "AMERICAN ADVISORS GROUP'   ATYA0N7",
#  "TAMERICAN ADVISORS GROUP'   AA/2AOIE  A/S/AOUZ    88]    BNDORSED 1] A 6A5] AS] TNT RAT TAY   3590",
#  'AMERICAN ADVISORS GROUT   A /O/AONE   IE/IZAOIE     A NDORSED "  ASSO ES] PA IY AS00',
#  "AMERICAN ADVISORS GROUP'   A/FOON7",
#  "AMERICAN ADVISORS GROUP' __   AZ/TOY2016",
#  "AMERICAN ADVISORS GROUP'   AZ/IAZYAOI6",
#  "TAMERICAN ADVISORS GROUP'   ATY20I7",
#  "AMERICAN ADVISORS GROUP'   A/ZOOI7",
#  "AMERICAN ADVISORS GROUP'   A/TOVAOI7",
#  "AMERICAN ADVISORS GROUP'   6162017",
#  "AMERICAN ADVISORS GROUP'   A/ZYO0N7",
#  "TAMERICAN ADVISORS GROUP'   TZ/ZOI7  OVEVEOUZ ]  ]   BNDORSED   585] 5.06] A6 F'N§ TAT TT AY   3500",
#  "AMERICAN ADVISORS GROUP'   FO FA0N7",
#  "AMERICAN ADVISORS GROUP'   N/5A0N7",
#  "AMERICAN ADVISORS GROUP' A7 FO0I7",
#  'AMERICAN ADVISORS GROUP   A/AFO0NS   AVER/OOIS    TA E    ENDORSED "  4.903506] ZANY TA TUT TIY\'   S650',
#  "AMERICAN ADVISORS GROUP'   /TFO0N7",
#  'TAMERICAN ADVISORS GROUP 722018',
#  'TAMBRICAN ADVISORS GROUP   TANI',
#  'TAMERICAN ADVISORS GROUT 71672018',
#  "AMERICAN ADVISORS GRUP'   220I",
#  'AMERICAN ADVISORS GROUPT   A/ZZOOIS   A/S/GOIS    NDORSED "  AGES] 06] ES F*NT TA TIY\' 300000] ASZ4O0[ 50',
#  "AMERICAN ADVISORS GROUP' _   ATAYZ0IS",
#  "AMERICAN ADVISORS GROUP'   6",
#  "AMERICAN ADVISORS GROUP'   8920S] G/AO/2OIG          ENDORSED *   A.GA7] 5.06] OZ YY TAH UTY TG 796",
#  'AMERICAN ADVISORS GROUP\'   A/ZFOOIS   /A/ZOIS    GF NDORSED "  STESSO NH TA TIV 620000 3906',
#  'TAMERICAN ADVISORS GROUT   17',
#  "AMERICAN ADVISORS GRUP' __—   T",
#  "TAMERICAN ADVISORS GROUP'   TIS",
#  "AMERICAN ADVISORS GROUP'   A/ZAYA0I9",
#  "AMERICAN ADVISORS GROUP'   9A /O0I8",
#  "AMERICAN ADVISORS GROUP' _—   94AM   VE",
#  "AMERICAN ADVISORS GROUP'   A2 /2018",
#  "TAMERICAN ADVISORS GROUP'   A/OYZOI9  _2V",
#  "AMERICAN ADVISORS GROUP'   A/AZFOON9",
#  "AMERICAN ADVISORS GROUP'   A/OVZOIG  SI/AOIG    RA]   ENDORSED '   5.042] ASI] OPIN RAT TV   TZ00",
#  "AMERICAN ADVISORS GROUP' _—   AVUGYAONG",
#  'AMERICAN ADVISORS GROUP\'   ATIZ0R9  3AG/ZOI9    TF   NDORSED "  5.379F 2] TEH TAT IY\'   5000',
#  "AMERICAN ADVISORS GROUP'   AITYANIG",
#  "AMERICAN ADVISORS GROUP'   AVIGYZ0I9",
#  'AMERICAN ADVISORS GROUP\'   AFAR] AYAAFOOIG  TWN A NDORSED "  ASONFO6F ES TNE TA TIV 3000',
#  "AMERICAN ADVISORS GROUP'   Z/AYZNIG",
#  "AMERICAN ADVISORS GROUP'   AZ /O020",
#  "AMERICAN ADVISORS GROUP'   A/ZFO0N0",
#  "TAMERICAN ADVISORS GROUP'   47",
#  "AMERICAN ADVISORS GROUP'   Z/AD/O020",
#  "AMERICAN ADVISORS GROUP'   9 /20",
#  'AMERICAN ADVISORS GROUPY 9A /2020',
#  "AMERICAN ADVISORS GOUP' __—   G",
#  "AMERICAN ADVISORS GROUP'   GYZOZI",
#  "TAMBRICAN ADVISORS GROUP'   N/2020]A/IS/AOAN    TO] PA RNDORSED '] 3.226) SA] GOFTNY FRAT AYE   AASO",
#  "AMERICAN ADVISORS GROUP'   /TY2020  IE/ZOAN        BNDORSED * FF 2] TEH YH YT ZA50",
#  "TAMERICAN ADVISORS GROUP'   Z0VZ0AN",
#  'AMERICAN. ADVISORS GROUP',
#  'AMERICAN ADVISORS GROUP" T/AT/2013',
#  'AMERICAN, ADVISORS GROUP',
#  "TAMERICAN ADVISORS GROUP' AVE",
#  "AMERICAN ADVISORS GROUP' _—   TZYA0UI",
#  "TAMBRICAN ADVISORS GROUP   A/Z0NN GA/EON   ]   ASSIGNED '] 5.06) 5.06] FH I50",
#  "AMERICAN ADVISORS GROUP' _—   682010",
#  "AMERICAN ADVISORS GROUP' _—   TO/IGV2OI0  IZ",
#  "TAMERICAN ADVISORS GROUP'   OAN} TAYO/EOUNF FA} ENDORSED '{ 5.06) 5.06] OFT 60",
#  "AMERICAN ADVISORS GROUP'   TOISYOOUI  IVAI/2OI1  S/I/AOI7] _       TERMINATED'   5.06] 5.06] ANH TT 50000) 00650] 30",
#  "AMERICAN ADVISORS GROUP'   TOEE",
#  "TAWERICAN ADVISORS GROUP' AZZ} AVE/AOUZ    EA] TA]  TNDORSED   A6) A5] A FT AE RE0",
#  "AMERICAN ADVISORS GROUP'   TZU",
#  "TAMERICAN ADVISORS GROUP' 8132011",
#  "TAMERICAN ADVISORS GROUP' AYAA] AFIS/AOIZ}   SS] OF ASSIGNED '   5.06) 5. 06  OTT TE S30",
#  "AMERICAN ADVISORS GROUP'   ZY20NG",
#  "TAMERICAN ADVISORS GROUP'   TTGYZ0I2",
#  "TAMERICAN ADVISORS GROUP'   ATAYZ0IS  AVE/20I3",
#  "AMERICAN ADVISORS GROUP'   ATGVZOIS  S/US/EOIS}   WZ]   ASSIGNED '   5.06) 5.06  OFT TH 30",
#  "AMERICAN ADVISORS GROUP'   ATGY20N3",
#  "AMERICAN ADVISORS GROUP' _   A/2YA0I3",
#  "TAMERICAN ADVISORS GROUP'   TZ/ANIS  S/ESVEOIS    TA] 8] ASSIGNED '   5.06) 5.06] OTT TE 550",
#  'TAMERICAN ADVISORS GROUP 7222013',
#  "AMERICAN ADVISORS GROUP' T/A /AOIS  IZ/E",
#  "TAMERICAN ADVISORS GROUP'   AA/A5FAOIS",
#  "TAMERICAN ADVISORS GROUP'   TAZ0IA",
#  'TAMERICAN ADVISORS GROUP 2E/A0IA A/O/EORAT TA] AF   TINDORSED TP OF 5. BAF AE FINE A T620',
#  "AMERICAN ADVISORS GROUP'   A4Z0NA",
#  "TAMBRICAN ADVISORS GROUP'   22014",
#  'TAMERICAN ADVISORS GROUP   2AAOIA',
#  "TAMERICAN ADVISORS GROUP'   ATS2Z0IA] 6YS/ZOUA    TI] 8S]  TNDORSED 1] TSA) SOF ST AT ZO0",
#  "TAMERICAN ADVISORS GROUP'   T2014",
#  "TAMERICAN ADVISORS GROUP' T",
#  'TAMERICAN ADVISORS GROUP 22014] 9',
#  "AMERICAN ADVISORS GROUP'   AT /20IS",
#  'AMERICAN ADVISORS GROUP\'  G F20N4  TOVAO/2ZOI4      GA]   BNDORSED "  2.529] 5.045   75 TNH YH   2050',
#  "AMERICAN ADVISORS GROUP'   TI /2014",
#  "TAMERICAN ADVISORS GROUP'   TA",
#  "AMERICAN ADVISORS GROUP'   TOF F20N4   UIE/OOIA  TWA     ENDORSED “  5.06 06 ONE A050",
#  "AMERICAN ADVISORS GROUP'   ANE F20N4  12",
#  "AMERICAN ADVISORS GROUP'   A/2IFA0IS",
#  "AMERICAN ADVISORS GROUP'   AZTZ/AOIA",
#  "AMERICAN ADVISORS GROUP'   AZFAMIS",
#  "AMERICAN ADVISORS GROUP'   A/ZYAOIS AFI",
#  "AMERICAN ADVISORS GROUP'   A/T2015",
#  'AMERICAN ADVISORS GROUPY   A2 /OOIS',
#  "AMERICAN ADVISORS GROUP'   A/2ZA0I5",
#  "AMERICAN ADVISORS GROUP' A /AYAOIAL AVEI/EOIS",
#  "AMERICAN ADVISORS GROUP'   272015",
#  "AMERICAN ADVISORS GROUP'   2A /A0IS",
#  "TAMERICAN ADVISORS GROUP'   ZYAOIS  A/ED/AOIS  U/E/EORS  5]     TERMINATED'   2.924) A 86] 7ST TAE 50",
#  "TAMERICAN ADVISORS GROUP'   TT20I5",
#  'AMERICAN ADVISORS GROUP\'   ATGY20IS   6YI/ZOIS        BNDORSED "  AUS] 96 5 RE TAH YT 5 50',
#  "AMERICAN ADVISORS GROUP'   5 /TYA0IS",
#  "AMERICAN ADVISORS GROUP' TA",
#  "TAMERICAN ADVISORS GROUP'   ZTAZOIS  A/II/AOIE",
#  "AMERICAN ADVISORS GROUP'   1A",
#  "TAMERICAN ADVISORS GROUP'   AA/IZOIS  AZ/SI/AOIS    RA}    TINDORSED   Z.GOAF TOF EZ FN AE T0",
#  "AMERICAN ADVISORS GROUP' AZZ AOIS",
#  "AMERICAN ADVISORS GROUP'   2TZ/2016",
#  "AMERICAN ADVISORS GROUP'   5 /UYO0I6",
#  'TAMERICAN ADVISORS GROUT   A8 /A0I6  P',
#  'AMERICAN ADVISORS GROUP\'   A/5 FOIE] G/IG/ZOIE    TS   TA]   ENDORSED "  ASS] ASS]. FTNT PA TAY 23000] AGIZ02[ 42',
#  "AMERICAN ADVISORS GROUP'   9162016] TO/IZ/ZOIS    SS]   ENDORSED 1] A G07] 5] TNT TAT AVE 30",
#  'AMERICAN ADVISORS GROUT   AA/AOEONE   AZ',
#  "AMERICAN ADVISORS GROUP' TO /TY20N6",
#  "TAMERICAN ADVISORS GROUP'   232017] S/AI/EOI7  SOVA/AOR7  82]     TORMINATED'   5.235) 5.9 FUT RAT AY 2 380",
#  'TAMERICAN ADVISORS GROUP\'   Z620I7 AVANEOUZ   ]    BNDORSED "  4.608 5.055] 75  \'NE RAT TAY   TP0',
#  "AMERICAN ADVISORS GROUP'   AZZOI7  S/AN/EOUZ ]   TA]   ENDORSED   578] 5.055] 75  'NÉ TAT TT AY   TZ00[ ITZ] 26",
#  "AMERICAN ADVISORS GROUP'   5407",
#  'TAMERICAN ADVISORS GROUP   ZAYZOI7',
#  "AMERICAN ADVISORS GROUP'   8TZ0I7",
#  'TAMERICAN ADVISORS GROUP   TOVZ0I7  OVE/AOUZ  TA] AF  TINDORSED "  4.603] 5.06] ESS FEE TAT TAY 20',
#  "AMERICAN ADVISORS GROUP'   TZYZ0R7  GA/AOUZ ]   WS]    ENDORSED '   5.06) 5.06] OTT TH TOG",
#  'AMERICAN ADVISORS GROUP\'   TOIGYOOI7  UIS/ZOR7 _   SOF]   BNDORSED "  4613] 5.06] I FTNH TA YT   2000',
#  "AMERICAN ADVISORS GROUP' __   T",
#  'AMERICAN ADVISORS GROUP   AAASFOON7   AA',
#  "TAMERICAN ADVISORS GROUP' 17",
#  'TAMERICAN ADVISORS GROUP 72AA0IS',
#  'AMERICAN ADVISORS GROUP   AP/ZFOOI7',
#  "AMERICAN ADVISORS GROUP'   3 9Z0IS",
#  "TAMERICAN ADVISORS GROUP' 220I",
#  "AMERICAN ADVISORS GROUP'   TZ20IS",
#  "TAMERICAN ADVISORS GROUP' 2920S",
#  "AMERICAN ADVISORS GROUP'   A/TY2Z0US",
#  "AMERICAN ADVISORS GROUP'   A/ZAYAOIS A/I",
#  "AMERICAN ADVISORS GROUP'   ASS",
#  'TAMBRICAN ADVISORS GROUP   ANAYOOIS  S/IFAOIS  A]   BNDORSED [5.348] 5.06] AFTE FRAT ET AY AZ90',
#  "TAMERICAN ADVISORS GROUP'   ZAYZOIS  AFIOVEOIS    A]    BNDORSED   A 5I5] AS] OTT RAT TAY   SAS0",
#  "AMERICAN ADVISORS GROUP' 220I",
#  'TAMERICAN ADVISORS GROUP" 8152018',
#  "TAMERICAN ADVISORS GROUP'   TZZOIS",
#  'AMERICAN ADVISORS GROUP\'   ATZ/Z0NS   TOVE/20I8    TA 83] 2 BNDORSED "  A.OI2] 5.055] A5 NY TAH YT 30',
#  "AMERICAN ADVISORS GROUP'   A/Y2018",
#  'TAMERICAN ADVISORS GROUP\'   TOVZ0I8  S/SOVEOIS    8]     "ENDORSED \'   A 7E7] A3 96 TNT TAT TAY   3060',
#  'TAMBRICAN ADVISORS GROUT 87',
#  'AMERICAN ADVISORS GROUP\'   9A FOIS] VOZ]   TAF NDORSED "  5.346] SAZ FTNY TA IY 2600',
#  "TAMERICAN ADVISORS GROUP'   8AZOIG",
#  "AMERICAN ADVISORS GROUP'   TOISYOOUS  TI/I",
#  "AMERICAN ADVISORS GROUP' A /Z620I8",
#  'TAMERICAN ADVISORS GROUP   A/OYZNI9  S/AG/AONP   ]     TINDORSED {56',
#  "AMERICAN ADVISORS GROUP'   A/ZAZQNG",
#  "AMERICAN ADVISORS GROUP'   A/AZAZ019",
#  "TAMERICAN ADVISORS GROUP'   A/AGVAZON9",
#  "AMERICAN ADVISORS GROUP'   882019] OVIS/ZOI9    GF   A RNDORSED *   436] 8.93] ONY TAT NYT 392000] 95216",
#  "AMERICAN ADVISORS GROUP'   @/T",
#  "TAMERICAN ADVISORS GROUP'   TOVZ0I9",
#  'TAMERICAN ADVISORS GROUPT TAZO',
#  "TAMERICAN ADVISORS GROUP' TS /20I9",
#  "TAMERICAN ADVISORS GROUP   Z/OYZ0I9  I/IO/2OZ0  SVIZ/EOZI  83] 80]   TERMINATED'   5.602) ST] SFT TAT TAY 30",
#  "AMERICAN ADVISORS GROUP' _—   A/AZYA0R9] I",
#  'AMERICAN ADVISORS GROUP\' _   TOIS20I9  RI/IS/ZOI9        2 ENDORSED "  4.006] 8. 56  A5 RY TA NAY\' 50',
#  "TAMERICAN ADVISORS GROUP   AT Z020  AR/AOZOF   8]    BNDORSED 1] 5.537] 5.8] SZ F'N§ RAT TAY 50",
#  "AMERICAN ADVISORS GROUP'   A/DFO020",
#  "TAMERICAN ADVISORS GROUP' __   ZYZ",
#  "AMERICAN ADVISORS GROUP' _—   4 /20",
#  'TAMERICAN ADVISORS GROUT 27',
#  'AMERICAN ADVISORS GROUT   AF /2020',
#  "AMERICAN ADVISORS GROUP'   A/ZDYAZ020",
#  "AMERICAN ADVISORS GROUP' _—   GT/2020",
#  "AMERICAN ADVISORS GROUP'   Z/ZFA0N0",
#  'TAMERICAN ADVISORS GROUP™ 10',
#  "AMERICAN ADVISORS GROUP'   NF /2020",
#  'AMERICAN ADVISORS GROUT   T',
#  'AMERICAN ADVISORS GROUP™ A /2D/O020',
#  "AMERICAN ADVISORS GROUP' __—   AA/IZ2Z020",
#  "AMERICAN ADVISORS GROUP' __—   TO/IZ/2Z020  1I/I",
#  "TAMERICAN ADVISORS GROUP' ANF /2020] 12",
#  "TAMERICAN ADVISORS GROUP' SY2OAN",
#  'TAMBRICAN ADVISORS GROUP   ATA A020]A/AA/EOAN    TA]   BNDORSED ] ASA7] SAO FTNE FRAT AYE A20000[TSAG60] 52',
#  'AMERICAN ADVISORS GROUPY A2',
#  "AMERICAN ADVISORS GROUP' TT /2020  A/IS/AOAT   ]   ENDORSED '   2.50)   AGE TAY 15",
#  "AMERICAN ADVISORS GROUP' __   A/ZZYAZ0ZI",
#  'AMERICAN ADVISORS GROUP\'   AYZOZI  AVA/AOAI          ENDORSED "  28A] 56] AR) YH TY\' 70000) TAGSO',
#  "AMERICAN ADVISORS GROUP'   A/Z0A0ZI",
#  "AMERICAN ADVISORS GROUP' _—   GAAN] 2",
#  "TAMERICAN ADVISORS GROUP'   ATZZOUN   S/AAVEOUR    TO]   ASSIGNED '   5.06) 5.06] OF 70",
#  "TAMERICAN ADVISORS GROUP'   AZAAOUN  S/ENVEOUN    TO] A] ASSIGNED '{ 5.06) 5.06] OTT TE 780",
#  "AMERICAN ADVISORS GROUP'   5TZY2Z0NI",
#  "TAMERICAN ADVISORS GROUP'   ATTZ0UN",
#  "AMERICAN ADVISORS GROUP'   A/30V20U1  AZO]   GF TA]   ENDORSED *   2.748] 5.96] SY YH A'   AZ00",
#  "AMERICAN ADVISORS GROUP'   A/ZZFAONI",
#  "AMERICAN ADVISORS GROUP'   5A /AONI",
#  "AMERICAN ADVISORS GROUP'   5TYA0NI",
#  'AMERICAN ADVISORS GROUT   84 FZ0NI',
#  "TAMERICAN ADVISORS GROUP'   AZIZONN  I/ES/EOUZ 2VI/EOUS  8] 2]   TERMINATED'   5.06) 5.06] OTT TE 0",
#  'TAMERICAN ADVISORS GROUP   27',
#  "AMERICAN ADVISORS GROUP'   AZO",
#  "AMERICAN ADVISORS GROUP'   AN /20NI",
#  "TAMERICAN ADVISORS GROUP'   TA2ZOIN",
#  "AMERICAN ADVISORS GROUP'   AZ/ZYAONI",
#  "AMERICAN ADVISORS GROUP'   AF YOOIZ",
#  "AMERICAN ADVISORS GROUP'   A/FA0IZ",
#  "AMERICAN ADVISORS GROUP'   /T/2012",
#  "AMERICAN ADVISORS GROUP'   TAMI",
#  "AMERICAN ADVISORS GROUP'   2A /O0IZ   A/IS/E0I2",
#  "AMERICAN ADVISORS GROUP' _—   A/ZAYAOI2  A/IG/2OI2        ASSIGNED ‘  5.06] 5.06] ATH HT A800",
#  "TAMERICAN ADVISORS GROUP' __   ZYAOIE  AVE",
#  "TAMERICAN ADVISORS GROUP'   8T",
#  "TAMERICAN ADVISORS GROUP' 232012] S/IE/AOUZ    TO]  TINDORSED 1] TAN] AS] FUT AE ZIZ0",
#  'TAMERICAN ADVISORS GROUT   A7 /20I2',
#  "AMERICAN ADVISORS GROUP' AZZ FAOI2",
#  'AMERICAN ADVISORS GROUP\'   ATZ/A0NZ   O/IA/ZOI2      ASSIGNED "  5.06] 5.06] OTH TE 3600',
#  'AMERICAN ADVISORS GROUP\'   84202] OVER/ZOI2        ASSIGNED "  5.06] 5.06] OTH TE P080',
#  'AMERICAN ADVISORS GROUP\'   AZYA0I2 I/IS/ZOI3 _       NDORSED "  5.06] 5.06] OTH TE 5 Z50',
#  "AMERICAN ADVISORS GROUP'   A/I/A0R2",
#  'AMERICAN ADVISORS GROUP\' AON} AVIN/AOI3       BNDORSED "  2.709 A 85] TEH YH IE 5 50',
#  'TAMERICAN ADVISORS GROUP\'   9262012] I/IS/AOIZ   ] 8] ASSIGNED "  5.06) 5.06] OFT 50',
#  "AMERICAN ADVISORS GROUP'   TT",
#  "AMERICAN ADVISORS GROUP' TA /A/AZ012",
#  ...]

# %%
# Use .loc to find rows where 'lender' contains 'GMFS' and update the 'lender' column
final_df.loc[final_df['lender'].str.contains('ADVISORS', na=False), 'lender'] = 'AMERICAN ADVISORS GROUP'

# %%
final_df['lender'].nunique(dropna=False)
# Out:
# 30189

# %% [markdown]
# #### FINANCIAL FREEDOM SENIOR FUNDING CORP

# %%
# Returns unique values that contain a particular string
search_string = "OR FUN"

# na=False handles rows with missing data so the code doesn't error out
list(final_df[final_df['lender'].str.contains(search_string, na=False)]['lender'].unique())
# Out:
# ['PINANCIAL FREEDOM SENIOR FUNDING CORP',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP',
#  'PINANCTAL FREEDOM SENTOR FUNDING CORP',
#  'RINANCTAL FREEDOM SENTOR FUNDING CORP',
#  'BINANCIAL FREEDOM SENIOR FUNDING CORP',
#  'RINANCIAL FREEDOM SENIOR FUNDING CORP',
#  'PINANCIAL FREEDOM SENTOR FUNDING CORP',
#  'TRINANCIAL FREEDOM SENIOR FUNDING CORP',
#  'FINANCTAL FREEDOM SENIOR FUNDING CORP',
#  'PINANCTAL FREEDOM SENIOR FUNDING CORP',
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   AZ/A/2006",
#  'RINANCTAL FREEDOM SENIOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' _____I",
#  'TRINANCTAL FREEDOM SENIOR FUNDING CORP',
#  'FINANCIAL FREEDOM SENTOR FUNDING CORP',
#  'FINANCIAL FREEDOM SENJOR FUNDING CORP',
#  'BINANCTAL FREEDOM SENIOR FUNDING CORP',
#  'FINANCIAL FREEDON SENIOR FUNDING CORP',
#  'TFINANCIAL FREEDOM SENIOR FUNDING CORP',
#  'TBINANCIAL FREEDOM SENIOR FUNDING CORP',
#  'TFINANCTAL FREEDOM SENIOR FUNDING CORP',
#  'TFINANCIAL FREEDOM SENTOR FUNDING CORP',
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/AZ/2007",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   N",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___—I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' _____—I",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   A/T",
#  "FINANCIAL FREEDON SENIOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A",
#  "BINANCTAL FREEDOM SENIOR FUNDING CORP'   A/A/2007",
#  "TRINANCIAL FREEDOM SENIOR FUNDING CORP'   17",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ____—I",
#  "TFINANCIAL FREEDOM SENTOR FUNDING CORP'   A/T/2007",
#  "BINANCTAL FREEDOM SENIOR FUNDING CORP'   A/AS/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TI /2007]_S/IS/EOOR ]   6]    ENDORSED ' {6 A8) PS TNT AY 95",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/I",
#  'TEINANCIAL FREEDOM SENIOR FUNDING CORP',
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/A/2007",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   A/AI/2007",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/AS/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ____I",
#  'FINANCIAL FREEDOM SENLOR FUNDING CORP',
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   A/TZ/2007",
#  "TFINANCTAL FREEDOM SENIOR FUNDING CORP'   A",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/TI/2007",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/A",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   N",
#  "TRINANCTAL FREEDOM SENIOR FUNDING CORP'  I /A/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __—__—I",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   1A",
#  'FINANCIAL FREDO SENIOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TO/II/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   S",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   TO/TI/2007  TI/IE/2007    SF ASSIGNED 52 SZ] ATH YEE YT 70",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TO",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   N",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _TO/AI/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   S",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __—I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   TO/IS/2007",
#  "BINANCIAL FREEDOM SENIOR FUNDING CORP'   AA/2I/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   TO/AI/2007",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   A/A/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __—I _T",
#  'TPINANCTAL FREEDOM SENIOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   S/O/2007",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   N",
#  "FINANCIAL FREEDOM SENTOR FUNDING CORP'   UI7",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   U",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   A/A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   UI",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TI",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   I",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/3I/2008",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   17",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   A",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ______—I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ____ _T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   A/I",
#  "TEINANCIAL FREEDOM SENIOR FUNDING CORP'   17",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/T",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   AS/A/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/I/2008",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   AVTU/ZOO1",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP' ____ _T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/TI/2002",
#  'TFINANCIAL FREEDON SENIOR FUNDING CORP',
#  "TFINANCTAL FREEDOM SENIOR FUNDING CORP'   A/3I/2003",
#  "TRINANCIAL FREEDOM SENIOR FUNDING CORP'   11",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TO/I4Y20O4  1I/I",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ____— TO",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   1A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/I",
#  "TFINANCTAL FREEDOM SENIOR FUNDING CORP'   /4Y2005  A/II/2006    TS   TA]   ASSIGNED *   5.76] 5.73] SH WH YT TAT00",
#  "BINANCTAL FREEDOM SENIOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   A",
#  'TFINANCIAL FREEDOM SENLOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___—_—I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' _   TO/AI/2006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _T",
#  "BINANCTAL FREEDOM SENIOR FUNDING CORP'   1A/A",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   AU//2006",
#  "TEINANCIAL FREEDOM SENIOR FUNDING CORP'   117",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   AN/I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   UI/2I/2006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/U",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   AZ",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   A/A",
#  "TFINANCIAL FREEDON SENIOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/2I/2007",
#  "TFINANCTAL FREEDOM SENIOR FUNDING CORP'   A/TI/2007",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/1Z/2007",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   UI",
#  "FINANCIAL FREEDON SENIOR FUNDING CORP'   T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___—I T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _TO/II/2007",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   AA /I/2007 II/A",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   S",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   TI/2I/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TO/I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _TO/AI/2007  1I/AI/2007  _I/E/AOZI] 7] 8D]   TERMINATED'   A.G7  39) ATH YT YT   A950",
#  "BINANCIAL FREEDOM SENIOR FUNDING CORP'   AU",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   AN",
#  'TBINANCTAL FREEDOM SENIOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   IZ/I",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/T/2008",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/TI/2008",
#  "TEINANCIAL FREEDOM SENIOR FUNDING CORP'   77",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __—_—I",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP' __ _T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __—* _T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TN",
#  "TEINANCIAL FREEDOM SENIOR FUNDING CORP'   11",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TA/TI/2008",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   UN",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   I/I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   /2I/2009",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   A/IG/2009",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   S/2I/2005",
#  "TFINANCTAL FREEDOM SENIOR FUNDING CORP'  I",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   AZ/I/2006",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   117",
#  'EINANCIAL FREEDOM SENIOR FUNDING CORP',
#  'RINANCIAL FREEDOM SENTOR FUNDING CORP',
#  'FINANCTAL FREEDOM SENTOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   N",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP' ____I",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   I",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/1I/2006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   1I/I/2006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   U",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A /A/2007",
#  "BINANCIAL FREEDOM SENIOR FUNDING CORP'   U",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'  I",
#  "FINANCIAL FREEDOM SENTOR FUNDING CORP'   _6",
#  "TEINANCIAL FREEDOM SENIOR FUNDING CORP'   1172172003",
#  "FINANCIAL FREEDOM SENTOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   IS/2I/2003",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   1Z/A/2003",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/2I/2005",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/T4Y2005",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _TO/3I/2005",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ____—I _T",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/2I/2005",
#  'FINANCIAL FREEDOM SNJOR FUNDING CORP',
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   AS",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ____—_—I",
#  "TEINANCIAL FREEDOM SENIOR FUNDING CORP'   1171572006",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   TI /2007",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/TI/2007",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   Z/T/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   S/OY2007",
#  'IBINANCIAL FREEDOM SENIOR FUNDING CORP',
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   TO/T",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'  I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   SO/I/2007 AI",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __   S",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   /I/2007",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   A/AI/2008",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   T",
#  "FINANCIAL FREEDOM SENTOR FUNDING CORP'   N",
#  "FINANCIAL FREEDOM SNJOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _TS/I",
#  "TFINANCIAL FREEDOM SENTOR FUNDING CORP'   UI",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ____I T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/2GV2008",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   A/IZ/2009",
#  'INANCIAL FREEDOM SENIOR FUNDING CORP',
#  'INANCIAL FREEDOM SENTOR FUNDING CORP',
#  'PINANCIAL FREEDOM SENIOR FUNDING CORP" I',
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   /A/2001",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _1U",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   I/2I/2005",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   AU/I/2007",
#  'RINANCLAL FREEDOM SENIOR FUNDING CORP',
#  'PLNANCLAL FREEDOM SENIOR FUNDING CORP',
#  'PINANCTAL FREEDOM SENIOR FUNDING CORP" L',
#  'PINANCTAL FREEDOM SENIOR FUNDING CORP" T',
#  'PINANCTAL FREEDOM SENIOR FUNDING CORP" LI',
#  'BINANCIAL FREEDOM SENIOR FUNDING CORP" T/A',
#  'AMERICAN. SENTOR FUNDING CORPORATION',
#  'PINANCTAL FREEDOM SENIOR FUNDING CORP" T/A/1999',
#  'AMERICAN SENIOR FUNDING CORPORATION',
#  'PINANCIAL FREEDOM SENIOR FUNDING CORP 71',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' T",
#  'AMERICAN. SENIOR FUNDING CORPORATION',
#  'PINANCTAL FREEDOM SENIOR FUNDING CORP" T/AL/2007',
#  'RINANCLAL FREEDOM SENIOR FUNDING CORP" T',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP" T/1T/2007',
#  'FINANCTAL. FREEDOM SENTOR FUNDING CORP',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 1U282004',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 11302008 3',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 87372004',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 78200',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 977001 VEZ002',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 61282002',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 8302002',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 4252003',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 942003',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 8142003',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 127872003',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP 12447003',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP NI/2I/1997',
#  'PINANCIAL FREEDOM SENIOR FUNDING CORP" T',
#  'BINANCIAL FREEDOM SENIOR FUNDING CORP" T/AT/2007',
#  'AMERICAN SENTOR FUNDING CORPORATION',
#  'EINANCIAL FREEDOM SENIOR FUNDING CORP" T/AT/2007',
#  'PINANCIAL FREEDOW SENIOR FUNDING CORP',
#  'FINANCIAL FREEDOM SENIOR FUNDING CORP" T/T/2007',
#  'PINANCIAL FREEDOM SENIOR FUNDING CORP T/1T/2007',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __I",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   A/T",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/TI 72001 3",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   _A/T",
#  "FINANCIAL FREEDON SENIOR FUNDING CORP'   N/O/2O01",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __—   S",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP' ___   I/I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TI/I",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   AA",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' _____ _T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   TI/I",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP' ___ _T",
#  "TRINANCIAL FREEDOM SENIOR FUNDING CORP'   1172672003",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   A",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   1A/1I/2004",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TA/II/2004",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   1Z",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   UI/1I/ZO04",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   12A /2004",
#  "TEINANCIAL FREEDOM SENIOR FUNDING CORP'   47",
#  'TPINANCIAL FREEDOM SENTOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___—_——I",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP' ___   T",
#  "TRINANCTAL FREEDOM SENIOR FUNDING CORP'   1A/2I/2005",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TS/2GY2005",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   UI",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   AZ/I/2005",
#  "TRINANCIAL FREEDOM SENIOR FUNDING CORP'   117",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/AI/2006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   A/3I/2006",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   A/2I/2006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TO/II/2006",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/A/2006",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   TI",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   AI",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   11",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   AI/A/2006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   /3I/2007",
#  "TRINANCIAL FREEDOM SENIOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/TI/2O07",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/ISY2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/TI/2007",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   AS",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   UI/2I/2007",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'  I /I/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   AI/I/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   S/Y2007",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   1A/2I/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TA/I",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   N/I32007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   AZ/II/2007",
#  "TFINANCIAL FREEDON SENIOR FUNDING CORP'   A/2I/2008",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   6",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _TO/SI/20O08",
#  "FINANCIAL FREDO SENIOR FUNDING CORP'   UI/2I/2O08  I",
#  "TEINANCIAL FREEDOM SENIOR FUNDING CORP'   1172572008",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   AZ/II/2O08  _IS/2009}       ENDORSED *   AAA] AT] TR) YH YT   3500",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   /T",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/AZ/2009",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   A/O/ZO09",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   1N/T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   UN/2I/2003",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   UI/1I/2004",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   I/I/2004",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   UI/1I/2004",
#  "FINANCIAL FREEDON SENIOR FUNDING CORP'   TN",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   1A/AI/2004",
#  "FINANCIAL FREEDOM SENLOR FUNDING CORP'   S",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/3I/2007",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   AA/2I/2007",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   A/1I/2008",
#  'TFINANCIAL FREDO SENIOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TS/2GV2007",
#  "BINANCIAL FREEDOM SENIOR FUNDING CORP'   43 /20",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   TO/I",
#  "FINANCIAL FREEDOM SENTOR FUNDING CORP'   T/2I/2002} I",
#  "FINANCIAL FREEDON SENIOR FUNDING CORP'   UN/2I/2002",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   TO",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   1N/I",
#  "FINANCIAL FREEDON SENIOR FUNDING CORP'   UI/1I/2004] I",
#  "TRINANCIAL FREEDOM SENIOR FUNDING CORP'   47",
#  "TEINANCIAL FREEDOM SENIOR FUNDING CORP'   1172172006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/3I/2007",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/3I/2007",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'  I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   TO/AI/2007  TI/AI/207 _   TZ}   ENDORSED *] AG7] 39} AH YH YT 93000) TS7A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   TS",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/AI/2008",
#  'TEINANCIAL FREEDOM SENTOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/AI/2001",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/AI/2001",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ____ _TI/I",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   /S/2001",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/2I/2003",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   1172572002",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   TI/2I/2002] A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/1I/2003",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   11",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   UI/2I/ZO03",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   I/A/2004",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   TI/I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   S/I/2004",
#  "TRINANCTAL FREEDOM SENIOR FUNDING CORP'  I",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   TI/T",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   AS",
#  "TRINANCTAL FREEDOM SENIOR FUNDING CORP'   1A/II/2004",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __   TA",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TA/1I/2004",
#  'RINANCIAL FREEDON SENIOR FUNDING CORP',
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   TO/2I/2005",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TS/2I/2005",
#  'FINANCIAL FREEDOM SENJOR FUNDING CORP\'   AVTT/ZO07] _S/V/AZOOR ]  ] OF  "TNDORSED \'   5.04) 568} AT AY 30',
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   ASA /2007  12",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TS",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   AI/I",
#  'TRINANCIAL FREEDOM SENTOR FUNDING CORP',
#  "BINANCTAL FREEDOM SENIOR FUNDING CORP'   A/A",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   TO/I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __—_—* _T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TI/2I/2008",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   1172172008",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   A/AI/2001",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   AU/I/AZO01",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   S/I/2002",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' _—I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   AI/I/2004",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   AI/TI/2004",
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   T",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   TA/2I/2006",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   TO/TI/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _TO/3I/2008",
#  "BINANCTAL FREEDOM SENIOR FUNDING CORP'  I /I/2006",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   11",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _A",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP' ___   A/I",
#  "FINANCIAL FREEDOM SENTOR FUNDING CORP'   I",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __   A/I",
#  'TRINANCIAL FREEDON SENIOR FUNDING CORP',
#  "FINANCTAL FREEDOM SENIOR FUNDING CORP'   TA/2I/2006",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/A/200I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __   A/AI/2003",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   TS/2I/2003",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   1S/2I/2003",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   1I/I",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   AU",
#  "TBINANCIAL FREEDOM SENIOR FUNDING CORP'   A/2I/2005",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   1N",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/TI/2006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TS/2I/20O06",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   TO/TI/2006",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/TT/2007",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/AI/2007",
#  'TPINANCIAL FREEDOM SENIOR FUNDING CORP',
#  "BINANCIAL FREEDOM SENIOR FUNDING CORP'   A",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __   G/3I/2007 A/AI/AOO7 _       ENDORSED *   5.22] 58] OG NY YH YT   A950",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   S/2I/2007",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   S",
#  "BINANCIAL FREEDOM SENIOR FUNDING CORP'   T",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP' __   T",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP' ____ T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ____—I T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __   TO/I",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   /I/2007 TI/E",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   AI/A/2007",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/TI/2008",
#  "TRINANCIAL FREEDOM SENIOR FUNDING CORP'   1172672007",
#  "BINANCTAL FREEDOM SENIOR FUNDING CORP'   AZ",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/TI/2008",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' __—_——I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   TO/2I/2008",
#  "FINANCIAL FREEDOM SENTOR FUNDING CORP'   1I",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___ _I",
#  "TFINANCIAL FREEDOM SENIOR FUNDING CORP'   1I",
#  "PINANCTAL FREEDOM SENIOR FUNDING CORP'   A/2I/2008",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/IZ/2009",
#  "TFINANCTAL FREEDOM SENIOR FUNDING CORP'   A/2I/2009",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP' ___   A/2GV2009",
#  "RINANCTAL FREEDOM SENIOR FUNDING CORP'   A/2I/2009",
#  "FINANCIAL FREEDOM SENJOR FUNDING CORP'   A/T",
#  "FINANCIAL FREEDOM SENIOR FUNDING CORP'   A/I/2009"]

# %%
# Use .loc to find rows where 'lender' contains 'GMFS' and update the 'lender' column
final_df.loc[final_df['lender'].str.contains('OR FUN', na=False), 'lender'] = 'FINANCIAL FREEDOM SENIOR FUNDING CORP'

# %%
final_df['lender'].nunique(dropna=False)
# Out:
# 29766
